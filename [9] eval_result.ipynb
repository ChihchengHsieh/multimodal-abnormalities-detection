# %%
import os, gc, torch, PIL

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from utils.eval import save_iou_results
from utils.engine import xami_evaluate
from models.load import get_trained_model
from utils.coco_eval import get_eval_params_dict
from data.dataset import ReflacxDataset, OurRadiologsitsDataset
from data.dataset import collate_fn
from utils.transforms import get_transform
from our_radiologist.load import get_anns
from utils.coco_eval import get_ar_ap
from utils.print import print_title

## Suppress the assignement warning from pandas.
pd.options.mode.chained_assignment = None  # default='warn

## Supress user warning
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %matplotlib inline

# %%
gc.collect()
# torch.cuda.memory_summary(device=None, abbreviated=False)

use_gpu = torch.cuda.is_available()
device = 'cuda' if use_gpu else 'cpu'
print(f"This notebook will running on device: [{device}]")

if use_gpu:
    torch.cuda.empty_cache()
# Out:
# This notebook will running on device: [cuda]

# %%
XAMI_MIMIC_PATH = "D:\XAMI-MIMIC"

use_clinical = False
use_custom_modal = False
use_early_stop_model=True

# %% [markdown]
# # Setup evaluation parameters

# %%
from dataclasses import dataclass

# score_thres = {
#     "Enlarged cardiac silhouette": 0.3,
#     "Atelectasis": 0.2,
#     "Pleural abnormality": 0.1,
#     "Consolidation": 0.05,
#     "Pulmonary edema": 0.1,
# }

@dataclass
class ModelSetup:
    use_clinical: bool
    use_custom_modal: bool   
    use_early_stop_model: bool
    name: str

all_model_setups = [
    # ModelSetup(
    #     name="original",
    #     use_clinical= False,
    #     use_custom_modal=False,
    #     use_early_stop_model= True,
    # ),
    #     ModelSetup(
    #     name="custom_without_clinical",
    #     use_clinical= False,
    #     use_custom_modal=True,
    #     use_early_stop_model= True,
    # ),
        ModelSetup(
        name="custom_with_clinical",
        use_clinical= True,
        use_custom_modal=True,
        use_early_stop_model= True,
    )
]

# %% [markdown]
# # Run evaluation.

# %%
for model_setup in all_model_setups:

    dataset_params_dict = {
        "XAMI_MIMIC_PATH": XAMI_MIMIC_PATH,
        "with_clinical": model_setup.use_clinical,
        "using_full_reflacx": False,
        "bbox_to_mask": True,
        "labels_cols": [
            "Enlarged cardiac silhouette",
            "Atelectasis",
            "Pleural abnormality",
            "Consolidation",
            "Pulmonary edema",
            #  'Groundglass opacity', # 6th disease.
        ],
    }

    detect_eval_dataset = ReflacxDataset(
        **{**dataset_params_dict, "using_full_reflacx": False,},
        transforms=get_transform(train=False),
    )

    test_dataset = ReflacxDataset(
        **dataset_params_dict, split_str="test", transforms=get_transform(train=False),
    )

    val_dataset = ReflacxDataset(
        **dataset_params_dict, split_str="val", transforms=get_transform(train=False),
    )

    val_dataloader = torch.utils.data.DataLoader(
        val_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn,
    )
    test_dataloader = torch.utils.data.DataLoader(
        test_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn,
    )

    radiologists_ann = get_anns("radiologists_annotated", detect_eval_dataset)

    radiologist_dataset = OurRadiologsitsDataset(detect_eval_dataset, radiologists_ann)

    radiologist_dataloader = torch.utils.data.DataLoader(
        radiologist_dataset, batch_size=4, shuffle=False, collate_fn=collate_fn,
    )

    model, model_path = get_trained_model(
        detect_eval_dataset,
        use_early_stop_model=model_setup.use_early_stop_model,
        use_custom_modal=model_setup.use_custom_modal,
        use_clinical=model_setup.use_clinical,
        device=device,
    )

    model.eval()

    normal_iou_thrs = np.array([0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95])
    normal_eval_params_dict = get_eval_params_dict(detect_eval_dataset, iou_thrs=normal_iou_thrs)

    all_range_iou_thrs = np.array([0.00, 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.])
    all_range_eval_params_dict = get_eval_params_dict(detect_eval_dataset, iou_thrs=all_range_iou_thrs)

    model.roi_heads.score_thresh = 0.05

    all_cat_ids = [None] + [
        detect_eval_dataset.disease_to_idx(d) for d in detect_eval_dataset.labels_cols
    ]

    for cat_id in all_cat_ids:
        cat_ids = (
            [
                detect_eval_dataset.disease_to_idx(d)
                for d in detect_eval_dataset.labels_cols
            ]
            if cat_id is None
            else [cat_id]
        )
        if not (cat_ids is None):
            normal_eval_params_dict["bbox"].catIds = cat_ids
            normal_eval_params_dict["segm"].catIds = cat_ids

        test_evaluator = xami_evaluate(
            model,
            test_dataloader,
            device=device,
            params_dict=normal_eval_params_dict,
            # score_thres=score_thres,
        )

        val_evaluator = xami_evaluate(
            model,
            val_dataloader,
            device=device,
            params_dict=normal_eval_params_dict,
            # score_thres=score_thres,
        )

        radiologist_evaluator = xami_evaluate(
            model,
            radiologist_dataloader,
            device=device,
            params_dict=normal_eval_params_dict,
        )

        if cat_id is None:
            disease_str = "all"
        else:
            disease_str = detect_eval_dataset.label_idx_to_disease(cat_id)

        test_ar, test_ap = get_ar_ap(
            test_evaluator, areaRng="all", maxDets=10, iouThr=None
        )
        val_ar, val_ap = get_ar_ap(
            val_evaluator, areaRng="all", maxDets=10, iouThr=None
        )
        our_ar, our_ap = get_ar_ap(
            radiologist_evaluator, areaRng="all", maxDets=10, iouThr=None
        )

        df = pd.DataFrame(
            [
                {
                    "dataset": "test",
                    "AP@[IoU = 0.50:0.95]": test_ap,
                    "AR@[IoU = 0.50:0.95]": test_ar,
                },
                {
                    "dataset": "val",
                    "AP@[IoU = 0.50:0.95]": val_ap,
                    "AR@[IoU = 0.50:0.95]": val_ar,
                },
                {
                    "dataset": "our",
                    "AP@[IoU = 0.50:0.95]": our_ap,
                    "AR@[IoU = 0.50:0.95]": our_ar,
                },
            ]
        )

        df.to_csv(os.path.join("eval_results", f"{model_path}_{disease_str}.csv"))
        print_title(disease_str)
        print(df)

    for cat_id in all_cat_ids:
        cat_ids = (
            [
                detect_eval_dataset.disease_to_idx(d)
                for d in detect_eval_dataset.labels_cols
            ]
            if cat_id is None
            else [cat_id]
        )
        if not (cat_ids is None):
            all_range_eval_params_dict["bbox"].catIds = cat_ids
            all_range_eval_params_dict["segm"].catIds = cat_ids

        test_evaluator = xami_evaluate(
            model,
            test_dataloader,
            device=device,
            params_dict=all_range_eval_params_dict,
            # score_thres=score_thres,
        )

        val_evaluator = xami_evaluate(
            model,
            val_dataloader,
            device=device,
            params_dict=all_range_eval_params_dict,
            # score_thres=score_thres,
        )

        radiologist_evaluator = xami_evaluate(
            model,
            radiologist_dataloader,
            device=device,
            params_dict=all_range_eval_params_dict,
        )

        if cat_id is None:
            disease_str = "all"
        else:
            disease_str = detect_eval_dataset.label_idx_to_disease(cat_id)

        save_iou_results(test_evaluator, f"test_{disease_str}", model_path)
        save_iou_results(val_evaluator, f"val_{disease_str}", model_path)
        save_iou_results(radiologist_evaluator, f"our_{disease_str}", model_path)
# Out:
# {'rpn_nms_thresh': 0.3, 'box_detections_per_img': 6, 'box_nms_thresh': 0.2, 'rpn_score_thresh': 0.0, 'box_score_thresh': 0.05}
# c1
# None
# creating index...
# index created!
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:02:13  model_time: 4.0611 (4.0611)  evaluator_time: 0.2599 (0.2599)  time: 5.1309  data: 0.7089  max mem: 1199
# Test:  [25/26]  eta: 0:00:01  model_time: 0.2731 (0.3998)  evaluator_time: 0.4540 (0.4224)  time: 1.4054  data: 0.6233  max mem: 1668
# Test: Total time: 0:00:40 (1.5555 s / it)
# Averaged stats: model_time: 0.2731 (0.3998)  evaluator_time: 0.4540 (0.4224)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.167
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.169
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:41  model_time: 0.3336 (0.3336)  evaluator_time: 0.5674 (0.5674)  time: 1.6103  data: 0.6363  max mem: 1668
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1909 (0.1919)  evaluator_time: 0.3499 (0.3412)  time: 1.1377  data: 0.5381  max mem: 1668
# Test: Total time: 0:00:30 (1.1582 s / it)
# Averaged stats: model_time: 0.1909 (0.1919)  evaluator_time: 0.3499 (0.3412)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.151
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.077
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.156
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:11  model_time: 0.2869 (0.2869)  evaluator_time: 0.5591 (0.5591)  time: 1.8750  data: 0.8780  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2869 (0.2948)  evaluator_time: 0.6048 (0.6172)  time: 1.9796  data: 0.9448  max mem: 1719
# Test: Total time: 0:00:11 (1.9799 s / it)
# Averaged stats: model_time: 0.2869 (0.2948)  evaluator_time: 0.6048 (0.6172)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.037
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.046
# ====================all====================
#   dataset  AP@[IoU = 0.50:0.95]  AR@[IoU = 0.50:0.95]
# 0    test              0.069019              0.166544
# 1     val              0.074248              0.151247
# 2     our              0.026730              0.036944
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:45  model_time: 0.3799 (0.3799)  evaluator_time: 0.6357 (0.6357)  time: 1.7316  data: 0.6480  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.2029 (0.2216)  evaluator_time: 0.3601 (0.3839)  time: 1.2458  data: 0.5837  max mem: 1719
# Test: Total time: 0:00:33 (1.2813 s / it)
# Averaged stats: model_time: 0.2029 (0.2216)  evaluator_time: 0.3601 (0.3839)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.471
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.467
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:40  model_time: 0.2981 (0.2981)  evaluator_time: 0.4690 (0.4690)  time: 1.5443  data: 0.6960  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.2410 (0.2481)  evaluator_time: 0.3620 (0.4039)  time: 1.3729  data: 0.6446  max mem: 1719
# Test: Total time: 0:00:36 (1.4101 s / it)
# Averaged stats: model_time: 0.2410 (0.2481)  evaluator_time: 0.3620 (0.4039)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.424
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.448
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:10  model_time: 0.2560 (0.2560)  evaluator_time: 0.5390 (0.5390)  time: 1.7890  data: 0.8460  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2419 (0.2445)  evaluator_time: 0.5270 (0.5143)  time: 1.7136  data: 0.8485  max mem: 1719
# Test: Total time: 0:00:10 (1.7138 s / it)
# Averaged stats: model_time: 0.2419 (0.2445)  evaluator_time: 0.5270 (0.5143)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.129
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.136
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.171
# ====================Enlarged cardiac silhouette====================
#   dataset  AP@[IoU = 0.50:0.95]  AR@[IoU = 0.50:0.95]
# 0    test              0.274657              0.470833
# 1     val              0.289788              0.423810
# 2     our              0.096686              0.129167
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:30  model_time: 0.1780 (0.1780)  evaluator_time: 0.2460 (0.2460)  time: 1.1730  data: 0.5420  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1990 (0.1899)  evaluator_time: 0.3730 (0.3440)  time: 1.1070  data: 0.4995  max mem: 1719
# Test: Total time: 0:00:29 (1.1233 s / it)
# Averaged stats: model_time: 0.1990 (0.1899)  evaluator_time: 0.3730 (0.3440)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.211
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.211
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:30  model_time: 0.2001 (0.2001)  evaluator_time: 0.3239 (0.3239)  time: 1.1830  data: 0.5100  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1810 (0.1813)  evaluator_time: 0.3231 (0.3195)  time: 1.0625  data: 0.4930  max mem: 1719
# Test: Total time: 0:00:28 (1.0782 s / it)
# Averaged stats: model_time: 0.1810 (0.1813)  evaluator_time: 0.3231 (0.3195)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.045
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.052
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:11  model_time: 0.3563 (0.3563)  evaluator_time: 0.5310 (0.5310)  time: 1.9450  data: 0.8540  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2410 (0.2597)  evaluator_time: 0.5240 (0.5168)  time: 1.7237  data: 0.8328  max mem: 1719
# Test: Total time: 0:00:10 (1.7240 s / it)
# Averaged stats: model_time: 0.2410 (0.2597)  evaluator_time: 0.5240 (0.5168)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.033
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.033
# ====================Atelectasis====================
#   dataset  AP@[IoU = 0.50:0.95]  AR@[IoU = 0.50:0.95]
# 0    test              0.057633              0.211111
# 1     val              0.007806              0.044828
# 2     our              0.035644              0.033333
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:31  model_time: 0.2684 (0.2684)  evaluator_time: 0.2901 (0.2901)  time: 1.2066  data: 0.5120  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1850 (0.1949)  evaluator_time: 0.3260 (0.3482)  time: 1.1157  data: 0.5139  max mem: 1719
# Test: Total time: 0:00:29 (1.1413 s / it)
# Averaged stats: model_time: 0.1850 (0.1949)  evaluator_time: 0.3260 (0.3482)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.027
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.033
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:34  model_time: 0.2460 (0.2460)  evaluator_time: 0.4750 (0.4750)  time: 1.3250  data: 0.5330  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1939 (0.1940)  evaluator_time: 0.3212 (0.3293)  time: 1.1194  data: 0.5135  max mem: 1719
# Test: Total time: 0:00:29 (1.1207 s / it)
# Averaged stats: model_time: 0.1939 (0.1940)  evaluator_time: 0.3212 (0.3293)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.085
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.080
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:11  model_time: 0.3810 (0.3810)  evaluator_time: 0.5540 (0.5540)  time: 1.9889  data: 0.8972  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2593 (0.2767)  evaluator_time: 0.5521 (0.5345)  time: 1.7918  data: 0.8715  max mem: 1719
# Test: Total time: 0:00:10 (1.7920 s / it)
# Averaged stats: model_time: 0.2593 (0.2767)  evaluator_time: 0.5521 (0.5345)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.022
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.028
# ====================Pleural abnormality====================
#   dataset  AP@[IoU = 0.50:0.95]  AR@[IoU = 0.50:0.95]
# 0    test              0.002256              0.026667
# 1     val              0.008048              0.085000
# 2     our              0.001320              0.022222
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:28  model_time: 0.2039 (0.2039)  evaluator_time: 0.2989 (0.2989)  time: 1.1138  data: 0.5460  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1990 (0.2004)  evaluator_time: 0.3421 (0.3541)  time: 1.1506  data: 0.5181  max mem: 1719
# Test: Total time: 0:00:30 (1.1591 s / it)
# Averaged stats: model_time: 0.1990 (0.2004)  evaluator_time: 0.3421 (0.3541)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.006
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.006
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:30  model_time: 0.2047 (0.2047)  evaluator_time: 0.3475 (0.3475)  time: 1.1883  data: 0.5310  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1979 (0.2039)  evaluator_time: 0.3129 (0.3363)  time: 1.1518  data: 0.5263  max mem: 1719
# Test: Total time: 0:00:30 (1.1555 s / it)
# Averaged stats: model_time: 0.1979 (0.2039)  evaluator_time: 0.3129 (0.3363)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.007
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.007
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:11  model_time: 0.3753 (0.3753)  evaluator_time: 0.5480 (0.5480)  time: 1.9530  data: 0.8740  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2566 (0.2726)  evaluator_time: 0.5400 (0.5316)  time: 1.7787  data: 0.8650  max mem: 1719
# Test: Total time: 0:00:10 (1.7790 s / it)
# Averaged stats: model_time: 0.2566 (0.2726)  evaluator_time: 0.5400 (0.5316)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
# ====================Consolidation====================
#   dataset  AP@[IoU = 0.50:0.95]  AR@[IoU = 0.50:0.95]
# 0    test              0.000462              0.006250
# 1     val              0.002640              0.007143
# 2     our              0.000000              0.000000
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:33  model_time: 0.2272 (0.2272)  evaluator_time: 0.4148 (0.4148)  time: 1.2758  data: 0.5278  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.2091 (0.2122)  evaluator_time: 0.3930 (0.3774)  time: 1.2633  data: 0.5634  max mem: 1719
# Test: Total time: 0:00:32 (1.2310 s / it)
# Averaged stats: model_time: 0.2091 (0.2122)  evaluator_time: 0.3930 (0.3774)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.118
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.129
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:30  model_time: 0.2020 (0.2020)  evaluator_time: 0.3643 (0.3643)  time: 1.1711  data: 0.5427  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1968 (0.2072)  evaluator_time: 0.3356 (0.3434)  time: 1.1903  data: 0.5669  max mem: 1719
# Test: Total time: 0:00:31 (1.1971 s / it)
# Averaged stats: model_time: 0.1968 (0.2072)  evaluator_time: 0.3356 (0.3434)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.195
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.195
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:10  model_time: 0.2501 (0.2501)  evaluator_time: 0.5321 (0.5321)  time: 1.8205  data: 0.9623  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2392 (0.2409)  evaluator_time: 0.5259 (0.5096)  time: 1.6980  data: 0.8552  max mem: 1719
# Test: Total time: 0:00:10 (1.6982 s / it)
# Averaged stats: model_time: 0.2392 (0.2409)  evaluator_time: 0.5259 (0.5096)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  6 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 10 ] = 0.000
# ====================Pulmonary edema====================
#   dataset  AP@[IoU = 0.50:0.95]  AR@[IoU = 0.50:0.95]
# 0    test              0.010086              0.117857
# 1     val              0.062958              0.195455
# 2     our              0.000000              0.000000
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:31  model_time: 0.2311 (0.2311)  evaluator_time: 0.2661 (0.2661)  time: 1.2107  data: 0.6456  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.2030 (0.2277)  evaluator_time: 0.3551 (0.3887)  time: 1.2318  data: 0.5709  max mem: 1719
# Test: Total time: 0:00:33 (1.3022 s / it)
# Averaged stats: model_time: 0.2030 (0.2277)  evaluator_time: 0.3551 (0.3887)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
# ...
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.051
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:10  model_time: 0.2541 (0.2541)  evaluator_time: 0.5291 (0.5291)  time: 1.7765  data: 0.8483  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2409 (0.2401)  evaluator_time: 0.5276 (0.5129)  time: 1.6850  data: 0.8283  max mem: 1719
# Test: Total time: 0:00:10 (1.6851 s / it)
# Averaged stats: model_time: 0.2409 (0.2401)  evaluator_time: 0.5276 (0.5129)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.027
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.027
# IoU [0.0000] | AR [0.1875] | AP [0.0482]
# IoU [0.0500] | AR [0.1875] | AP [0.0482]
# IoU [0.1000] | AR [0.1875] | AP [0.0482]
# IoU [0.1500] | AR [0.1875] | AP [0.0482]
# IoU [0.2000] | AR [0.1875] | AP [0.0482]
# IoU [0.2500] | AR [0.1250] | AP [0.0172]
# IoU [0.3000] | AR [0.0625] | AP [0.0046]
# IoU [0.3500] | AR [0.0625] | AP [0.0046]
# IoU [0.4000] | AR [0.0625] | AP [0.0046]
# IoU [0.4500] | AR [0.0625] | AP [0.0046]
# IoU [0.5000] | AR [0.0625] | AP [0.0046]
# IoU [0.5500] | AR [0.0000] | AP [0.0000]
# IoU [0.6000] | AR [0.0000] | AP [0.0000]
# IoU [0.6500] | AR [0.0000] | AP [0.0000]
# IoU [0.7000] | AR [0.0000] | AP [0.0000]
# IoU [0.7500] | AR [0.0000] | AP [0.0000]
# IoU [0.8000] | AR [0.0000] | AP [0.0000]
# IoU [0.8500] | AR [0.0000] | AP [0.0000]
# IoU [0.9000] | AR [0.0000] | AP [0.0000]
# IoU [0.9500] | AR [0.0000] | AP [0.0000]
# IoU [1.0000] | AR [0.0000] | AP [0.0000]
# IoU [0.0000] | AR [0.2143] | AP [0.0680]
# IoU [0.0500] | AR [0.1429] | AP [0.0403]
# IoU [0.1000] | AR [0.1429] | AP [0.0403]
# IoU [0.1500] | AR [0.0714] | AP [0.0264]
# IoU [0.2000] | AR [0.0714] | AP [0.0264]
# IoU [0.2500] | AR [0.0714] | AP [0.0264]
# IoU [0.3000] | AR [0.0714] | AP [0.0264]
# IoU [0.3500] | AR [0.0714] | AP [0.0264]
# IoU [0.4000] | AR [0.0714] | AP [0.0264]
# IoU [0.4500] | AR [0.0714] | AP [0.0264]
# IoU [0.5000] | AR [0.0714] | AP [0.0264]
# IoU [0.5500] | AR [0.0000] | AP [0.0000]
# IoU [0.6000] | AR [0.0000] | AP [0.0000]
# IoU [0.6500] | AR [0.0000] | AP [0.0000]
# IoU [0.7000] | AR [0.0000] | AP [0.0000]
# IoU [0.7500] | AR [0.0000] | AP [0.0000]
# IoU [0.8000] | AR [0.0000] | AP [0.0000]
# IoU [0.8500] | AR [0.0000] | AP [0.0000]
# IoU [0.9000] | AR [0.0000] | AP [0.0000]
# IoU [0.9500] | AR [0.0000] | AP [0.0000]
# IoU [1.0000] | AR [0.0000] | AP [0.0000]
# IoU [0.0000] | AR [0.1429] | AP [0.0673]
# IoU [0.0500] | AR [0.0714] | AP [0.0158]
# IoU [0.1000] | AR [0.0714] | AP [0.0158]
# IoU [0.1500] | AR [0.0714] | AP [0.0158]
# IoU [0.2000] | AR [0.0714] | AP [0.0158]
# IoU [0.2500] | AR [0.0714] | AP [0.0158]
# IoU [0.3000] | AR [0.0714] | AP [0.0158]
# IoU [0.3500] | AR [0.0000] | AP [0.0000]
# IoU [0.4000] | AR [0.0000] | AP [0.0000]
# IoU [0.4500] | AR [0.0000] | AP [0.0000]
# IoU [0.5000] | AR [0.0000] | AP [0.0000]
# IoU [0.5500] | AR [0.0000] | AP [0.0000]
# IoU [0.6000] | AR [0.0000] | AP [0.0000]
# IoU [0.6500] | AR [0.0000] | AP [0.0000]
# IoU [0.7000] | AR [0.0000] | AP [0.0000]
# IoU [0.7500] | AR [0.0000] | AP [0.0000]
# IoU [0.8000] | AR [0.0000] | AP [0.0000]
# IoU [0.8500] | AR [0.0000] | AP [0.0000]
# IoU [0.9000] | AR [0.0000] | AP [0.0000]
# IoU [0.9500] | AR [0.0000] | AP [0.0000]
# IoU [1.0000] | AR [0.0000] | AP [0.0000]
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:32  model_time: 0.2072 (0.2072)  evaluator_time: 0.3561 (0.3561)  time: 1.2471  data: 0.5128  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.1867 (0.1889)  evaluator_time: 0.3211 (0.3408)  time: 1.0760  data: 0.4939  max mem: 1719
# Test: Total time: 0:00:28 (1.1112 s / it)
# Averaged stats: model_time: 0.1867 (0.1889)  evaluator_time: 0.3211 (0.3408)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.108
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.371
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.381
# creating index...
# index created!
# Test:  [ 0/26]  eta: 0:00:33  model_time: 0.2631 (0.2631)  evaluator_time: 0.3351 (0.3351)  time: 1.2756  data: 0.5365  max mem: 1719
# Test:  [25/26]  eta: 0:00:01  model_time: 0.2020 (0.2145)  evaluator_time: 0.3294 (0.3493)  time: 1.1233  data: 0.5195  max mem: 1719
# Test: Total time: 0:00:31 (1.2106 s / it)
# Averaged stats: model_time: 0.2020 (0.2145)  evaluator_time: 0.3294 (0.3493)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.448
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.450
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:11  model_time: 0.3816 (0.3816)  evaluator_time: 0.5633 (0.5633)  time: 1.9111  data: 0.8872  max mem: 1719
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2787 (0.3124)  evaluator_time: 0.5591 (0.5730)  time: 1.9326  data: 0.9422  max mem: 1719
# Test: Total time: 0:00:11 (1.9327 s / it)
# Averaged stats: model_time: 0.2787 (0.3124)  evaluator_time: 0.5591 (0.5730)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.101
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.101
# IoU [0.0000] | AR [0.8571] | AP [0.3317]
# IoU [0.0500] | AR [0.8571] | AP [0.3317]
# IoU [0.1000] | AR [0.8214] | AP [0.3099]
# IoU [0.1500] | AR [0.8214] | AP [0.3099]
# IoU [0.2000] | AR [0.6786] | AP [0.2107]
# IoU [0.2500] | AR [0.6429] | AP [0.1997]
# IoU [0.3000] | AR [0.6429] | AP [0.1997]
# IoU [0.3500] | AR [0.5000] | AP [0.1236]
# IoU [0.4000] | AR [0.4643] | AP [0.1180]
# IoU [0.4500] | AR [0.3214] | AP [0.0335]
# IoU [0.5000] | AR [0.2500] | AP [0.0231]
# IoU [0.5500] | AR [0.2500] | AP [0.0231]
# IoU [0.6000] | AR [0.2500] | AP [0.0231]
# IoU [0.6500] | AR [0.2500] | AP [0.0231]
# IoU [0.7000] | AR [0.1429] | AP [0.0079]
# IoU [0.7500] | AR [0.0357] | AP [0.0005]
# IoU [0.8000] | AR [0.0000] | AP [0.0000]
# IoU [0.8500] | AR [0.0000] | AP [0.0000]
# IoU [0.9000] | AR [0.0000] | AP [0.0000]
# IoU [0.9500] | AR [0.0000] | AP [0.0000]
# IoU [1.0000] | AR [0.0000] | AP [0.0000]
# IoU [0.0000] | AR [0.8636] | AP [0.3140]
# IoU [0.0500] | AR [0.8182] | AP [0.2812]
# IoU [0.1000] | AR [0.8182] | AP [0.2812]
# IoU [0.1500] | AR [0.8182] | AP [0.2812]
# IoU [0.2000] | AR [0.8182] | AP [0.2812]
# IoU [0.2500] | AR [0.8182] | AP [0.2812]
# IoU [0.3000] | AR [0.6818] | AP [0.2262]
# IoU [0.3500] | AR [0.6818] | AP [0.2262]
# IoU [0.4000] | AR [0.5909] | AP [0.2004]
# IoU [0.4500] | AR [0.5455] | AP [0.1919]
# IoU [0.5000] | AR [0.5000] | AP [0.1847]
# IoU [0.5500] | AR [0.4091] | AP [0.1728]
# IoU [0.6000] | AR [0.4091] | AP [0.1728]
# IoU [0.6500] | AR [0.2727] | AP [0.0584]
# IoU [0.7000] | AR [0.1364] | AP [0.0198]
# IoU [0.7500] | AR [0.0909] | AP [0.0083]
# IoU [0.8000] | AR [0.0909] | AP [0.0083]
# IoU [0.8500] | AR [0.0455] | AP [0.0045]
# IoU [0.9000] | AR [0.0000] | AP [0.0000]
# IoU [0.9500] | AR [0.0000] | AP [0.0000]
# IoU [1.0000] | AR [0.0000] | AP [0.0000]
# IoU [0.0000] | AR [0.6250] | AP [0.1155]
# IoU [0.0500] | AR [0.5000] | AP [0.0808]
# IoU [0.1000] | AR [0.3750] | AP [0.0451]
# IoU [0.1500] | AR [0.2500] | AP [0.0206]
# IoU [0.2000] | AR [0.2500] | AP [0.0206]
# IoU [0.2500] | AR [0.1250] | AP [0.0051]
# IoU [0.3000] | AR [0.0000] | AP [0.0000]
# IoU [0.3500] | AR [0.0000] | AP [0.0000]
# IoU [0.4000] | AR [0.0000] | AP [0.0000]
# IoU [0.4500] | AR [0.0000] | AP [0.0000]
# IoU [0.5000] | AR [0.0000] | AP [0.0000]
# IoU [0.5500] | AR [0.0000] | AP [0.0000]
# IoU [0.6000] | AR [0.0000] | AP [0.0000]
# IoU [0.6500] | AR [0.0000] | AP [0.0000]
# IoU [0.7000] | AR [0.0000] | AP [0.0000]
# IoU [0.7500] | AR [0.0000] | AP [0.0000]
# IoU [0.8000] | AR [0.0000] | AP [0.0000]
# IoU [0.8500] | AR [0.0000] | AP [0.0000]
# IoU [0.9000] | AR [0.0000] | AP [0.0000]
# IoU [0.9500] | AR [0.0000] | AP [0.0000]
# IoU [1.0000] | AR [0.0000] | AP [0.0000]
