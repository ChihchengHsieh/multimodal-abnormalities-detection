# %%
import os, gc, torch, PIL, pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from utils.plot import disease_cmap
from utils.coco_eval import get_ar_ap, get_eval_params_dict
from our_radiologist.load import get_anns

from data.dataset import collate_fn
from utils.transforms import get_transform
from utils.pred import pred_thrs_check
from utils.engine import xami_evaluate
from models.load import get_trained_model

from models.load import TrainedModels
from collections import OrderedDict
from matplotlib.patches import Rectangle
from data.dataset import ReflacxDataset
from data.dataset import OurRadiologsitsDataset

## Suppress the assignement warning from pandas.
pd.options.mode.chained_assignment = None  # default='warn

## Supress user warning
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %matplotlib inline

# %%
gc.collect()
# torch.cuda.memory_summary(device=None, abbreviated=False)

use_gpu = torch.cuda.is_available()
device = 'cuda' if use_gpu else 'cpu'
print(f"This notebook will running on device: [{device}]")

if use_gpu:
    torch.cuda.empty_cache()
# Out:
# This notebook will running on device: [cuda]

# %%
# 0.23623015873015873 0.11900175731858897 (0.01, thrs)
# 0.35710317460317464 0.1440243872224295 (0.01, None)
# 0.22956349206349205 0.11206579987412377 (0.05, thrs)
# 0.35710317460317464 0.14248711487254806 (0.05, None)
# 0.21103174603174607 0.1446907131542274 (0.3, None)

# %%
for select_model in  TrainedModels:
    print(select_model.value)
# Out:
# val_ar_0_5230_ap_0_2576_test_ar_0_5678_ap_0_2546_epoch28_WithoutClincal_03-28-2022 06-56-13_original
# val_ar_0_4575_ap_0_2689_test_ar_0_4953_ap_0_2561_epoch40_WithoutClincal_03-28-2022 09-15-40_custom_without_clinical
# val_ar_0_5363_ap_0_2963_test_ar_0_5893_ap_0_2305_epoch36_WithClincal_03-28-2022 20-06-43_custom_with_clinical
# val_ar_0_5126_ap_0_2498_test_ar_0_5607_ap_0_2538_epoch18_WithClincal_03-28-2022 10-18-55_custom_with_clinical
# val_ar_0_3993_ap_0_2326_test_ar_0_4957_ap_0_2390_epoch50_WithClincal_03-28-2022 16-06-00_custom_with_clinical
# val_ar_0_4955_ap_0_2942_test_ar_0_5449_ap_0_2566_epoch28_WithClincal_03-28-2022 17-25-34_custom_with_clinical

# %%
XAMI_MIMIC_PATH =  "D:\XAMI-MIMIC"

labels_cols = [
    "Enlarged cardiac silhouette",
    "Atelectasis",
    "Pleural abnormality",
    "Consolidation",
    "Pulmonary edema",
    #  'Groundglass opacity', # 6th disease.
]

# %%
def save_iou_results(evaluator, suffix, model_path):
    ap_ar_dict = OrderedDict({thrs: []  for thrs in evaluator.coco_eval['bbox'].params.iouThrs})

    for thrs in evaluator.coco_eval['bbox'].params.iouThrs:
        test_ar, test_ap = get_ar_ap(
            evaluator,
            areaRng='all',
            maxDets= 10,
            iouThr=thrs,
        )

        ap_ar_dict[thrs].append({
            'ar': test_ar,
            'ap': test_ap,
        })

        print(f"[{thrs:.4f}] | AR [{test_ar:.4f}] | AP [{test_ap:.4f}]")

    ## iouThr=0.3
    # 0.5699603174603174 0.23895678925202643 (custom, with clinical)
    # 0.5992460317460317 0.2928311315704941 (custom, without clinical)
    # 0.5244047619047619 0.22751787710826604 (original, without clinical)

    with open(
        os.path.join("eval_results", f"{model_path}_{suffix}.pkl"), "wb",
    ) as training_record_f:
        pickle.dump(ap_ar_dict, training_record_f)

### iouThr=0.3, With score thrs.
# 0.45178571428571423 0.20556006215252126 (custom, with clinical)
# 0.481547619047619 0.25642166456776067 (custom, without clinical)
# 0.36710317460317465 0.1927187078516919(original, without clinical)

### IoBB Result

# %%
for select_model in  TrainedModels:
    model, train_info = get_trained_model(select_model, labels_cols, device, include_train_info=True)
    model.eval()

    dataset_params_dict = {
        "XAMI_MIMIC_PATH": XAMI_MIMIC_PATH,
        "with_clinical": train_info.model_setup.use_clinical,
        "dataset_mode": "unified",
        "bbox_to_mask": True,
        "labels_cols": labels_cols,
    }

    detect_eval_dataset = ReflacxDataset(
        **{**dataset_params_dict, "dataset_mode": "unified",},
        transforms=get_transform(train=False),
    )

    radiologists_anns = get_anns("radiologists_annotated", detect_eval_dataset)


    iou_thrs = np.array([0.00, 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.])
        
    eval_params_dict = get_eval_params_dict(detect_eval_dataset, iou_thrs=iou_thrs)

    test_dataset = ReflacxDataset(
        **dataset_params_dict, split_str="test", transforms=get_transform(train=False),
    )

    val_dataset = ReflacxDataset(
        **dataset_params_dict, split_str="val", transforms=get_transform(train=False),
    )

    val_dataloader = torch.utils.data.DataLoader(
        val_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn,
    )
    test_dataloader = torch.utils.data.DataLoader(
        test_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn,
    )

    radiologist_dataset = OurRadiologsitsDataset(detect_eval_dataset, radiologists_anns)

    radiologist_dataloader = torch.utils.data.DataLoader(
        radiologist_dataset, batch_size=4, shuffle=False, collate_fn=collate_fn,
    )

    model.roi_heads.score_thresh = 0.05

    score_thres= {
        'Enlarged cardiac silhouette': 0.3,
        'Atelectasis': 0.2,
        'Pleural abnormality': 0.1,
        'Consolidation': 0.05,
        'Pulmonary edema': 0.1,
    }

    test_evaluator = xami_evaluate(
        model,
        test_dataloader,
        device=device,
        params_dict=eval_params_dict,
        # score_thres=score_thres,
    )  

    val_evaluator = xami_evaluate(
        model,
        val_dataloader,
        device=device,
        params_dict=eval_params_dict,
        # score_thres=score_thres,
    )

    radiologist_evaluator = xami_evaluate(
            model, radiologist_dataloader, device=device, params_dict=eval_params_dict
    )

    save_iou_results(test_evaluator, "test", select_model.value)
    save_iou_results(val_evaluator, "val", select_model.value)
    save_iou_results(radiologist_evaluator, "our", select_model.value)
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/23]  eta: 0:01:25  model_time: 2.7627 (2.7627)  evaluator_time: 0.2422 (0.2422)  time: 3.7008  data: 0.5309  max mem: 2329
# Test:  [22/23]  eta: 0:00:01  model_time: 0.3301 (0.4320)  evaluator_time: 0.2801 (0.3158)  time: 1.2495  data: 0.5313  max mem: 2459
# Test: Total time: 0:00:31 (1.3693 s / it)
# Averaged stats: model_time: 0.3301 (0.4320)  evaluator_time: 0.2801 (0.3158)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.259
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.149
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.215
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.426
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.515
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.515
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.515
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.152
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.076
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.156
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.304
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.346
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.346
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.346
# creating index...
# index created!
# Test:  [ 0/22]  eta: 0:00:27  model_time: 0.3581 (0.3581)  evaluator_time: 0.3226 (0.3226)  time: 1.2518  data: 0.5101  max mem: 2459
# Test:  [21/22]  eta: 0:00:01  model_time: 0.3211 (0.3201)  evaluator_time: 0.2659 (0.2759)  time: 1.2106  data: 0.5423  max mem: 2459
# Test: Total time: 0:00:26 (1.2131 s / it)
# Averaged stats: model_time: 0.3211 (0.3201)  evaluator_time: 0.2659 (0.2759)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.257
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.179
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.390
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.494
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.494
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.494
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.153
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.035
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.166
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.256
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.319
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.319
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:12  model_time: 0.4451 (0.4451)  evaluator_time: 0.5251 (0.5251)  time: 2.1255  data: 0.9952  max mem: 2459
# Test:  [5/6]  eta: 0:00:01  model_time: 0.4021 (0.4082)  evaluator_time: 0.5161 (0.5263)  time: 1.9777  data: 0.9317  max mem: 2459
# Test: Total time: 0:00:11 (1.9780 s / it)
# Averaged stats: model_time: 0.4021 (0.4082)  evaluator_time: 0.5161 (0.5263)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.073
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.007
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.146
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.189
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.224
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.224
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.089
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.004
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.144
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.184
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.210
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.210
# [0.0000] | AR [0.7328] | AP [0.3237]
# [0.0500] | AR [0.6954] | AP [0.3044]
# [0.1000] | AR [0.6954] | AP [0.3044]
# [0.1500] | AR [0.6954] | AP [0.3044]
# [0.2000] | AR [0.6871] | AP [0.3026]
# [0.2500] | AR [0.6634] | AP [0.2936]
# [0.3000] | AR [0.6482] | AP [0.2872]
# [0.3500] | AR [0.6357] | AP [0.2838]
# [0.4000] | AR [0.6190] | AP [0.2795]
# [0.4500] | AR [0.5969] | AP [0.2661]
# [0.5000] | AR [0.5747] | AP [0.2587]
# [0.5500] | AR [0.5553] | AP [0.2414]
# [0.6000] | AR [0.5110] | AP [0.2242]
# [0.6500] | AR [0.4498] | AP [0.1925]
# [0.7000] | AR [0.4344] | AP [0.1839]
# [0.7500] | AR [0.3792] | AP [0.1490]
# [0.8000] | AR [0.3342] | AP [0.1201]
# [0.8500] | AR [0.2767] | AP [0.0806]
# [0.9000] | AR [0.2603] | AP [0.0664]
# [0.9500] | AR [0.2193] | AP [0.0341]
# [1.0000] | AR [0.1490] | AP [0.0175]
# [0.0000] | AR [0.7043] | AP [0.4159]
# [0.0500] | AR [0.6722] | AP [0.3859]
# [0.1000] | AR [0.6722] | AP [0.3859]
# [0.1500] | AR [0.6722] | AP [0.3859]
# [0.2000] | AR [0.6548] | AP [0.3660]
# [0.2500] | AR [0.6457] | AP [0.3535]
# [0.3000] | AR [0.6141] | AP [0.3120]
# [0.3500] | AR [0.5824] | AP [0.3006]
# [0.4000] | AR [0.5646] | AP [0.2917]
# [0.4500] | AR [0.5373] | AP [0.2744]
# [0.5000] | AR [0.5230] | AP [0.2570]
# [0.5500] | AR [0.5139] | AP [0.2498]
# [0.6000] | AR [0.4871] | AP [0.2258]
# [0.6500] | AR [0.4689] | AP [0.2200]
# [0.7000] | AR [0.4364] | AP [0.2055]
# [0.7500] | AR [0.3775] | AP [0.1794]
# [0.8000] | AR [0.3775] | AP [0.1794]
# [0.8500] | AR [0.3324] | AP [0.1375]
# [0.9000] | AR [0.2497] | AP [0.1016]
# [0.9500] | AR [0.1726] | AP [0.0708]
# [1.0000] | AR [0.1227] | AP [0.0406]
# [0.0000] | AR [0.7111] | AP [0.4586]
# [0.0500] | AR [0.5940] | AP [0.3809]
# [0.1000] | AR [0.5357] | AP [0.3670]
# [0.1500] | AR [0.4357] | AP [0.3325]
# [0.2000] | AR [0.3960] | AP [0.2973]
# [0.2500] | AR [0.3599] | AP [0.2818]
# [0.3000] | AR [0.3230] | AP [0.2550]
# [0.3500] | AR [0.2702] | AP [0.1988]
# [0.4000] | AR [0.2425] | AP [0.1641]
# [0.4500] | AR [0.1865] | AP [0.1078]
# [0.5000] | AR [0.1615] | AP [0.0728]
# [0.5500] | AR [0.1532] | AP [0.0695]
# [0.6000] | AR [0.1032] | AP [0.0265]
# [0.6500] | AR [0.0698] | AP [0.0195]
# [0.7000] | AR [0.0532] | AP [0.0098]
# [0.7500] | AR [0.0365] | AP [0.0066]
# [0.8000] | AR [0.0365] | AP [0.0066]
# [0.8500] | AR [0.0365] | AP [0.0066]
# [0.9000] | AR [0.0000] | AP [0.0000]
# [0.9500] | AR [0.0000] | AP [0.0000]
# [1.0000] | AR [0.0000] | AP [0.0000]
# {'rpn_nms_thresh': 0.3, 'box_detections_per_img': 6, 'box_nms_thresh': 0.2, 'rpn_score_thresh': 0.0, 'box_score_thresh': 0.05}
# c1
# None
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/23]  eta: 0:00:31  model_time: 0.3221 (0.3221)  evaluator_time: 0.3541 (0.3541)  time: 1.3500  data: 0.5458  max mem: 2459
# Test:  [22/23]  eta: 0:00:01  model_time: 0.1536 (0.1660)  evaluator_time: 0.2090 (0.2284)  time: 0.9968  data: 0.5561  max mem: 2459
# Test: Total time: 0:00:23 (1.0358 s / it)
# Averaged stats: model_time: 0.1536 (0.1660)  evaluator_time: 0.2090 (0.2284)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.256
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.203
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.452
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.493
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.493
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.493
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.170
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.063
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.310
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.335
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.335
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.335
# creating index...
# index created!
# Test:  [ 0/22]  eta: 0:00:26  model_time: 0.2976 (0.2976)  evaluator_time: 0.2641 (0.2641)  time: 1.1888  data: 0.5591  max mem: 2459
# Test:  [21/22]  eta: 0:00:00  model_time: 0.1440 (0.1481)  evaluator_time: 0.1945 (0.1831)  time: 0.9312  data: 0.5318  max mem: 2459
# Test: Total time: 0:00:20 (0.9368 s / it)
# Averaged stats: model_time: 0.1440 (0.1481)  evaluator_time: 0.1945 (0.1831)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.269
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.168
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.370
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.434
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.434
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.434
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.191
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.042
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.179
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.248
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.291
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.291
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.291
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:12  model_time: 0.4113 (0.4113)  evaluator_time: 0.5801 (0.5801)  time: 2.1587  data: 1.0172  max mem: 2459
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2264 (0.2599)  evaluator_time: 0.5116 (0.5128)  time: 1.8294  data: 0.9483  max mem: 2459
# Test: Total time: 0:00:10 (1.8294 s / it)
# Averaged stats: model_time: 0.2264 (0.2599)  evaluator_time: 0.5116 (0.5128)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.141
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.093
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.012
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.141
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.207
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.253
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.253
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.253
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.097
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.005
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.132
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.198
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.227
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.227
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.227
# [0.0000] | AR [0.6924] | AP [0.3572]
# [0.0500] | AR [0.6619] | AP [0.3352]
# [0.1000] | AR [0.6619] | AP [0.3352]
# [0.1500] | AR [0.6382] | AP [0.3242]
# [0.2000] | AR [0.6382] | AP [0.3242]
# [0.2500] | AR [0.6382] | AP [0.3242]
# [0.3000] | AR [0.6061] | AP [0.3149]
# [0.3500] | AR [0.5824] | AP [0.3102]
# [0.4000] | AR [0.5561] | AP [0.2897]
# [0.4500] | AR [0.5272] | AP [0.2730]
# [0.5000] | AR [0.4953] | AP [0.2561]
# [0.5500] | AR [0.4870] | AP [0.2437]
# [0.6000] | AR [0.4647] | AP [0.2189]
# [0.6500] | AR [0.4563] | AP [0.2174]
# [0.7000] | AR [0.4245] | AP [0.2053]
# [0.7500] | AR [0.4162] | AP [0.2030]
# [0.8000] | AR [0.3778] | AP [0.1809]
# [0.8500] | AR [0.3172] | AP [0.1346]
# [0.9000] | AR [0.3077] | AP [0.1206]
# [0.9500] | AR [0.2443] | AP [0.0864]
# [1.0000] | AR [0.1534] | AP [0.0403]
# [0.0000] | AR [0.6265] | AP [0.3895]
# [0.0500] | AR [0.5802] | AP [0.3530]
# [0.1000] | AR [0.5802] | AP [0.3530]
# [0.1500] | AR [0.5715] | AP [0.3385]
# [0.2000] | AR [0.5628] | AP [0.3326]
# [0.2500] | AR [0.5446] | AP [0.3274]
# [0.3000] | AR [0.5446] | AP [0.3274]
# [0.3500] | AR [0.5272] | AP [0.3140]
# [0.4000] | AR [0.5038] | AP [0.2884]
# [0.4500] | AR [0.4861] | AP [0.2820]
# [0.5000] | AR [0.4575] | AP [0.2689]
# [0.5500] | AR [0.4488] | AP [0.2664]
# [0.6000] | AR [0.4397] | AP [0.2515]
# [0.6500] | AR [0.4033] | AP [0.2169]
# [0.7000] | AR [0.3475] | AP [0.1775]
# [0.7500] | AR [0.3384] | AP [0.1682]
# [0.8000] | AR [0.3011] | AP [0.1555]
# [0.8500] | AR [0.2648] | AP [0.1202]
# [0.9000] | AR [0.2466] | AP [0.0984]
# [0.9500] | AR [0.1967] | AP [0.0498]
# [1.0000] | AR [0.1374] | AP [0.0219]
# [0.0000] | AR [0.6738] | AP [0.4173]
# [0.0500] | AR [0.5595] | AP [0.3175]
# [0.1000] | AR [0.5123] | AP [0.3015]
# [0.1500] | AR [0.4873] | AP [0.2939]
# [0.2000] | AR [0.4730] | AP [0.2860]
# [0.2500] | AR [0.4147] | AP [0.2645]
# [0.3000] | AR [0.3500] | AP [0.2311]
# [0.3500] | AR [0.3306] | AP [0.2054]
# [0.4000] | AR [0.2778] | AP [0.1648]
# [0.4500] | AR [0.2611] | AP [0.1447]
# [0.5000] | AR [0.2135] | AP [0.0933]
# [0.5500] | AR [0.1992] | AP [0.0803]
# [0.6000] | AR [0.1798] | AP [0.0709]
# [0.6500] | AR [0.1238] | AP [0.0457]
# [0.7000] | AR [0.0702] | AP [0.0117]
# [0.7500] | AR [0.0702] | AP [0.0117]
# [0.8000] | AR [0.0619] | AP [0.0108]
# [0.8500] | AR [0.0143] | AP [0.0020]
# [0.9000] | AR [0.0143] | AP [0.0020]
# [0.9500] | AR [0.0143] | AP [0.0020]
# [1.0000] | AR [0.0143] | AP [0.0020]
# {'rpn_nms_thresh': 0.3, 'box_detections_per_img': 6, 'box_nms_thresh': 0.2, 'rpn_score_thresh': 0.0, 'box_score_thresh': 0.05}
# c1
# None
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/23]  eta: 0:00:32  model_time: 0.2527 (0.2527)  evaluator_time: 0.4531 (0.4531)  time: 1.4029  data: 0.5512  max mem: 2459
# Test:  [22/23]  eta: 0:00:01  model_time: 0.1903 (0.1969)  evaluator_time: 0.3051 (0.3494)  time: 1.1488  data: 0.5304  max mem: 2459
# Test: Total time: 0:00:26 (1.1646 s / it)
# Averaged stats: model_time: 0.1903 (0.1969)  evaluator_time: 0.3051 (0.3494)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.230
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.135
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.213
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.460
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.541
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.541
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.541
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.119
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.028
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.137
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.302
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.338
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.338
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.338
# creating index...
# index created!
# Test:  [ 0/22]  eta: 0:00:33  model_time: 0.3781 (0.3781)  evaluator_time: 0.4826 (0.4826)  time: 1.5419  data: 0.5431  max mem: 2459
# Test:  [21/22]  eta: 0:00:01  model_time: 0.1918 (0.1970)  evaluator_time: 0.3036 (0.3161)  time: 1.1280  data: 0.5489  max mem: 2459
# Test: Total time: 0:00:25 (1.1431 s / it)
# Averaged stats: model_time: 0.1918 (0.1970)  evaluator_time: 0.3036 (0.3161)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.296
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.150
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.394
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.473
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.473
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.473
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.157
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.018
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.166
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.259
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.304
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.304
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:12  model_time: 0.4139 (0.4139)  evaluator_time: 0.5722 (0.5722)  time: 2.1579  data: 1.0188  max mem: 2459
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2571 (0.2872)  evaluator_time: 0.5611 (0.5537)  time: 1.9154  data: 0.9624  max mem: 2459
# Test: Total time: 0:00:11 (1.9157 s / it)
# Averaged stats: model_time: 0.2571 (0.2872)  evaluator_time: 0.5611 (0.5537)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.076
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.012
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.123
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.185
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.232
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.232
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.232
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.055
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.008
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.111
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.162
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.202
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.202
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.202
# [0.0000] | AR [0.7740] | AP [0.3612]
# [0.0500] | AR [0.7074] | AP [0.3196]
# [0.1000] | AR [0.7074] | AP [0.3196]
# [0.1500] | AR [0.6768] | AP [0.3067]
# [0.2000] | AR [0.6768] | AP [0.2975]
# [0.2500] | AR [0.6768] | AP [0.2975]
# [0.3000] | AR [0.6699] | AP [0.2960]
# [0.3500] | AR [0.6532] | AP [0.2859]
# [0.4000] | AR [0.6254] | AP [0.2610]
# [0.4500] | AR [0.6045] | AP [0.2488]
# [0.5000] | AR [0.5893] | AP [0.2304]
# [0.5500] | AR [0.5588] | AP [0.2170]
# [0.6000] | AR [0.5272] | AP [0.1971]
# [0.6500] | AR [0.5272] | AP [0.1971]
# [0.7000] | AR [0.5052] | AP [0.1762]
# [0.7500] | AR [0.4503] | AP [0.1349]
# [0.8000] | AR [0.4006] | AP [0.1062]
# [0.8500] | AR [0.3512] | AP [0.0844]
# [0.9000] | AR [0.2809] | AP [0.0560]
# [0.9500] | AR [0.2051] | AP [0.0378]
# [1.0000] | AR [0.1831] | AP [0.0343]
# [0.0000] | AR [0.7612] | AP [0.4155]
# [0.0500] | AR [0.6772] | AP [0.3630]
# [0.1000] | AR [0.6772] | AP [0.3630]
# [0.1500] | AR [0.6681] | AP [0.3609]
# [0.2000] | AR [0.6590] | AP [0.3567]
# [0.2500] | AR [0.6321] | AP [0.3375]
# [0.3000] | AR [0.5858] | AP [0.3168]
# [0.3500] | AR [0.5537] | AP [0.3037]
# [0.4000] | AR [0.5450] | AP [0.2995]
# [0.4500] | AR [0.5363] | AP [0.2963]
# [0.5000] | AR [0.5363] | AP [0.2963]
# [0.5500] | AR [0.5090] | AP [0.2824]
# [0.6000] | AR [0.4588] | AP [0.2360]
# [0.6500] | AR [0.4172] | AP [0.2078]
# [0.7000] | AR [0.3990] | AP [0.1937]
# [0.7500] | AR [0.3436] | AP [0.1501]
# [0.8000] | AR [0.2937] | AP [0.1337]
# [0.8500] | AR [0.2522] | AP [0.0808]
# [0.9000] | AR [0.2054] | AP [0.0584]
# [0.9500] | AR [0.1461] | AP [0.0421]
# [1.0000] | AR [0.0815] | AP [0.0063]
# [0.0000] | AR [0.6901] | AP [0.3975]
# [0.0500] | AR [0.5286] | AP [0.2980]
# [0.1000] | AR [0.4921] | AP [0.2765]
# [0.1500] | AR [0.3976] | AP [0.2562]
# [0.2000] | AR [0.3726] | AP [0.2511]
# [0.2500] | AR [0.3583] | AP [0.2259]
# [0.3000] | AR [0.3389] | AP [0.2042]
# [0.3500] | AR [0.2687] | AP [0.1544]
# [0.4000] | AR [0.2603] | AP [0.1400]
# [0.4500] | AR [0.2437] | AP [0.1167]
# [0.5000] | AR [0.1933] | AP [0.0763]
# [0.5500] | AR [0.1766] | AP [0.0548]
# [0.6000] | AR [0.1655] | AP [0.0492]
# [0.6500] | AR [0.1234] | AP [0.0307]
# [0.7000] | AR [0.1008] | AP [0.0209]
# [0.7500] | AR [0.0675] | AP [0.0118]
# [0.8000] | AR [0.0563] | AP [0.0097]
# [0.8500] | AR [0.0286] | AP [0.0026]
# [0.9000] | AR [0.0000] | AP [0.0000]
# [0.9500] | AR [0.0000] | AP [0.0000]
# [1.0000] | AR [0.0000] | AP [0.0000]
# {'rpn_nms_thresh': 0.3, 'box_detections_per_img': 6, 'box_nms_thresh': 0.2, 'rpn_score_thresh': 0.0, 'box_score_thresh': 0.05}
# c1
# None
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/23]  eta: 0:00:37  model_time: 0.3777 (0.3777)  evaluator_time: 0.5576 (0.5576)  time: 1.6115  data: 0.5521  max mem: 2459
# Test:  [22/23]  eta: 0:00:01  model_time: 0.2030 (0.2125)  evaluator_time: 0.3661 (0.3740)  time: 1.1917  data: 0.5327  max mem: 2459
# Test: Total time: 0:00:27 (1.2110 s / it)
# Averaged stats: model_time: 0.2030 (0.2125)  evaluator_time: 0.3661 (0.3740)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.254
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.181
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.232
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.428
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.512
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.512
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.512
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.138
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.034
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.156
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.295
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.342
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.342
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.342
# creating index...
# index created!
# Test:  [ 0/22]  eta: 0:00:25  model_time: 0.2080 (0.2080)  evaluator_time: 0.3683 (0.3683)  time: 1.1760  data: 0.5317  max mem: 2459
# Test:  [21/22]  eta: 0:00:01  model_time: 0.1860 (0.1921)  evaluator_time: 0.3302 (0.3212)  time: 1.1273  data: 0.5473  max mem: 2459
# Test: Total time: 0:00:25 (1.1372 s / it)
# Averaged stats: model_time: 0.1860 (0.1921)  evaluator_time: 0.3302 (0.3212)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.218
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.250
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.139
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.218
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.390
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.459
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.459
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.459
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.152
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.007
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.149
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.264
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.303
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.303
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:12  model_time: 0.3541 (0.3541)  evaluator_time: 0.5571 (0.5571)  time: 2.0704  data: 0.9921  max mem: 2459
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2541 (0.2713)  evaluator_time: 0.5341 (0.5369)  time: 1.8406  data: 0.9190  max mem: 2459
# Test: Total time: 0:00:11 (1.8408 s / it)
# Averaged stats: model_time: 0.2541 (0.2713)  evaluator_time: 0.5341 (0.5369)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.194
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.036
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.198
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.229
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.229
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.229
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.133
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.002
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.157
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.181
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.211
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.211
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.211
# [0.0000] | AR [0.7479] | AP [0.3690]
# [0.0500] | AR [0.6897] | AP [0.3349]
# [0.1000] | AR [0.6814] | AP [0.3217]
# [0.1500] | AR [0.6814] | AP [0.3217]
# [0.2000] | AR [0.6814] | AP [0.3217]
# [0.2500] | AR [0.6509] | AP [0.3045]
# [0.3000] | AR [0.6121] | AP [0.2914]
# [0.3500] | AR [0.5967] | AP [0.2795]
# [0.4000] | AR [0.5898] | AP [0.2632]
# [0.4500] | AR [0.5732] | AP [0.2588]
# [0.5000] | AR [0.5607] | AP [0.2538]
# [0.5500] | AR [0.5288] | AP [0.2372]
# [0.6000] | AR [0.5011] | AP [0.2282]
# [0.6500] | AR [0.4859] | AP [0.2180]
# [0.7000] | AR [0.4501] | AP [0.1891]
# [0.7500] | AR [0.4432] | AP [0.1806]
# [0.8000] | AR [0.3922] | AP [0.1573]
# [0.8500] | AR [0.3286] | AP [0.1239]
# [0.9000] | AR [0.2271] | AP [0.0568]
# [0.9500] | AR [0.1818] | AP [0.0463]
# [1.0000] | AR [0.1463] | AP [0.0348]
# [0.0000] | AR [0.7107] | AP [0.3520]
# [0.0500] | AR [0.6215] | AP [0.3245]
# [0.1000] | AR [0.6215] | AP [0.3245]
# [0.1500] | AR [0.6128] | AP [0.3192]
# [0.2000] | AR [0.5863] | AP [0.3003]
# [0.2500] | AR [0.5772] | AP [0.2990]
# [0.3000] | AR [0.5681] | AP [0.2970]
# [0.3500] | AR [0.5538] | AP [0.2663]
# [0.4000] | AR [0.5360] | AP [0.2563]
# [0.4500] | AR [0.5126] | AP [0.2498]
# [0.5000] | AR [0.5126] | AP [0.2498]
# [0.5500] | AR [0.4858] | AP [0.2416]
# [0.6000] | AR [0.4533] | AP [0.2184]
# [0.6500] | AR [0.3947] | AP [0.1756]
# [0.7000] | AR [0.3947] | AP [0.1756]
# [0.7500] | AR [0.3584] | AP [0.1394]
# [0.8000] | AR [0.3350] | AP [0.1360]
# [0.8500] | AR [0.2848] | AP [0.1089]
# [0.9000] | AR [0.2341] | AP [0.0816]
# [0.9500] | AR [0.1925] | AP [0.0536]
# [1.0000] | AR [0.1028] | AP [0.0180]
# [0.0000] | AR [0.6262] | AP [0.4232]
# [0.0500] | AR [0.5067] | AP [0.3555]
# [0.1000] | AR [0.4484] | AP [0.3399]
# [0.1500] | AR [0.4151] | AP [0.3320]
# [0.2000] | AR [0.4151] | AP [0.3320]
# [0.2500] | AR [0.3786] | AP [0.3195]
# [0.3000] | AR [0.3258] | AP [0.2692]
# [0.3500] | AR [0.2619] | AP [0.2092]
# [0.4000] | AR [0.2619] | AP [0.2092]
# [0.4500] | AR [0.2536] | AP [0.2007]
# [0.5000] | AR [0.2313] | AP [0.1943]
# [0.5500] | AR [0.1897] | AP [0.1273]
# [0.6000] | AR [0.1647] | AP [0.1062]
# [0.6500] | AR [0.0976] | AP [0.0433]
# [0.7000] | AR [0.0865] | AP [0.0419]
# [0.7500] | AR [0.0560] | AP [0.0356]
# [0.8000] | AR [0.0393] | AP [0.0285]
# [0.8500] | AR [0.0310] | AP [0.0272]
# [0.9000] | AR [0.0083] | AP [0.0009]
# [0.9500] | AR [0.0083] | AP [0.0009]
# [1.0000] | AR [0.0000] | AP [0.0000]
# {'rpn_nms_thresh': 0.3, 'box_detections_per_img': 6, 'box_nms_thresh': 0.2, 'rpn_score_thresh': 0.0, 'box_score_thresh': 0.05}
# c1
# None
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/23]  eta: 0:00:27  model_time: 0.2781 (0.2781)  evaluator_time: 0.2926 (0.2926)  time: 1.1828  data: 0.5411  max mem: 2459
# Test:  [22/23]  eta: 0:00:01  model_time: 0.1720 (0.1706)  evaluator_time: 0.2451 (0.2423)  time: 0.9839  data: 0.5248  max mem: 2459
# Test: Total time: 0:00:23 (1.0178 s / it)
# Averaged stats: model_time: 0.1720 (0.1706)  evaluator_time: 0.2451 (0.2423)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.239
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.161
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.208
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.361
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.450
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.450
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.450
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.169
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.068
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.163
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.281
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.339
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.339
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.339
# creating index...
# index created!
# Test:  [ 0/22]  eta: 0:00:26  model_time: 0.3231 (0.3231)  evaluator_time: 0.2351 (0.2351)  time: 1.2262  data: 0.5260  max mem: 2459
# Test:  [21/22]  eta: 0:00:01  model_time: 0.1480 (0.1679)  evaluator_time: 0.1890 (0.2093)  time: 0.9850  data: 0.5530  max mem: 2459
# Test: Total time: 0:00:22 (1.0016 s / it)
# Averaged stats: model_time: 0.1480 (0.1679)  evaluator_time: 0.1890 (0.2093)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.233
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.148
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.207
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.329
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.370
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.370
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.370
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.159
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.024
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.150
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.240
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.271
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.271
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.271
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:13  model_time: 0.3671 (0.3671)  evaluator_time: 0.6221 (0.6221)  time: 2.2580  data: 0.9797  max mem: 2459
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2421 (0.2613)  evaluator_time: 0.5240 (0.5123)  time: 1.8321  data: 0.9275  max mem: 2459
# Test: Total time: 0:00:10 (1.8323 s / it)
# Averaged stats: model_time: 0.2421 (0.2613)  evaluator_time: 0.5240 (0.5123)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.075
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.127
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.158
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.185
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.185
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.185
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.125
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.045
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.005
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.125
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.157
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.182
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.182
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.182
# [0.0000] | AR [0.6384] | AP [0.3425]
# [0.0500] | AR [0.5994] | AP [0.3061]
# [0.1000] | AR [0.5911] | AP [0.3005]
# [0.1500] | AR [0.5842] | AP [0.2940]
# [0.2000] | AR [0.5690] | AP [0.2796]
# [0.2500] | AR [0.5690] | AP [0.2796]
# [0.3000] | AR [0.5537] | AP [0.2670]
# [0.3500] | AR [0.5329] | AP [0.2552]
# [0.4000] | AR [0.5234] | AP [0.2493]
# [0.4500] | AR [0.5026] | AP [0.2423]
# [0.5000] | AR [0.4957] | AP [0.2388]
# [0.5500] | AR [0.4778] | AP [0.2184]
# [0.6000] | AR [0.4501] | AP [0.1963]
# [0.6500] | AR [0.4348] | AP [0.1811]
# [0.7000] | AR [0.4253] | AP [0.1738]
# [0.7500] | AR [0.3967] | AP [0.1611]
# [0.8000] | AR [0.3664] | AP [0.1513]
# [0.8500] | AR [0.3142] | AP [0.1143]
# [0.9000] | AR [0.2072] | AP [0.0512]
# [0.9500] | AR [0.1464] | AP [0.0265]
# [1.0000] | AR [0.0801] | AP [0.0101]
# [0.0000] | AR [0.5545] | AP [0.3295]
# [0.0500] | AR [0.5363] | AP [0.3039]
# [0.1000] | AR [0.5363] | AP [0.3039]
# [0.1500] | AR [0.5363] | AP [0.3039]
# [0.2000] | AR [0.5098] | AP [0.2843]
# [0.2500] | AR [0.4635] | AP [0.2635]
# [0.3000] | AR [0.4548] | AP [0.2612]
# [0.3500] | AR [0.4461] | AP [0.2595]
# [0.4000] | AR [0.4461] | AP [0.2595]
# [0.4500] | AR [0.4084] | AP [0.2428]
# [0.5000] | AR [0.3993] | AP [0.2326]
# [0.5500] | AR [0.3617] | AP [0.2063]
# [0.6000] | AR [0.3526] | AP [0.1991]
# [0.6500] | AR [0.3344] | AP [0.1846]
# [0.7000] | AR [0.2837] | AP [0.1482]
# [0.7500] | AR [0.2837] | AP [0.1482]
# [0.8000] | AR [0.2656] | AP [0.1422]
# [0.8500] | AR [0.2244] | AP [0.1282]
# [0.9000] | AR [0.1745] | AP [0.0752]
# [0.9500] | AR [0.1113] | AP [0.0398]
# [1.0000] | AR [0.0788] | AP [0.0119]
# [0.0000] | AR [0.5885] | AP [0.4112]
# [0.0500] | AR [0.4409] | AP [0.3011]
# [0.1000] | AR [0.4159] | AP [0.2960]
# [0.1500] | AR [0.3714] | AP [0.2790]
# [0.2000] | AR [0.3492] | AP [0.2776]
# [0.2500] | AR [0.3492] | AP [0.2776]
# [0.3000] | AR [0.2825] | AP [0.2015]
# [0.3500] | AR [0.2429] | AP [0.1727]
# [0.4000] | AR [0.2151] | AP [0.1416]
# [0.4500] | AR [0.1817] | AP [0.1008]
# [0.5000] | AR [0.1567] | AP [0.0752]
# [0.5500] | AR [0.1147] | AP [0.0562]
# [0.6000] | AR [0.0841] | AP [0.0383]
# [0.6500] | AR [0.0504] | AP [0.0191]
# [0.7000] | AR [0.0337] | AP [0.0097]
# [0.7500] | AR [0.0000] | AP [0.0000]
# [0.8000] | AR [0.0000] | AP [0.0000]
# [0.8500] | AR [0.0000] | AP [0.0000]
# [0.9000] | AR [0.0000] | AP [0.0000]
# [0.9500] | AR [0.0000] | AP [0.0000]
# [1.0000] | AR [0.0000] | AP [0.0000]
# {'rpn_nms_thresh': 0.3, 'box_detections_per_img': 6, 'box_nms_thresh': 0.2, 'rpn_score_thresh': 0.0, 'box_score_thresh': 0.05}
# c1
# None
# creating index...
# index created!
# creating index...
# index created!
# Test:  [ 0/23]  eta: 0:00:36  model_time: 0.3263 (0.3263)  evaluator_time: 0.4871 (0.4871)  time: 1.5946  data: 0.5311  max mem: 2459
# Test:  [22/23]  eta: 0:00:01  model_time: 0.1850 (0.1785)  evaluator_time: 0.3201 (0.2921)  time: 1.0412  data: 0.5002  max mem: 2459
# Test: Total time: 0:00:24 (1.0621 s / it)
# Averaged stats: model_time: 0.1850 (0.1785)  evaluator_time: 0.3201 (0.2921)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.257
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.170
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.229
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.433
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.491
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.491
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.491
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.143
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.080
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.157
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.278
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.323
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.323
# creating index...
# index created!
# Test:  [ 0/22]  eta: 0:00:29  model_time: 0.2221 (0.2221)  evaluator_time: 0.4221 (0.4221)  time: 1.3443  data: 0.5181  max mem: 2459
# Test:  [21/22]  eta: 0:00:01  model_time: 0.1690 (0.1741)  evaluator_time: 0.2496 (0.2771)  time: 1.0377  data: 0.5168  max mem: 2459
# Test: Total time: 0:00:23 (1.0488 s / it)
# Averaged stats: model_time: 0.1690 (0.1741)  evaluator_time: 0.2496 (0.2771)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.268
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.294
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.200
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.270
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.388
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.464
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.464
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.464
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.181
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.034
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.185
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.258
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.304
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.304
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:10  model_time: 0.2501 (0.2501)  evaluator_time: 0.5367 (0.5367)  time: 1.8198  data: 0.9591  max mem: 2459
# Test:  [5/6]  eta: 0:00:01  model_time: 0.2451 (0.2439)  evaluator_time: 0.5250 (0.5273)  time: 1.7532  data: 0.8852  max mem: 2459
# Test: Total time: 0:00:10 (1.7534 s / it)
# Averaged stats: model_time: 0.2451 (0.2439)  evaluator_time: 0.5250 (0.5273)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=   all | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.113
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = 0.004
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.147
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  1 ] = 0.194
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets=  6 ] = 0.226
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=   all | maxDets= 10 ] = 0.226
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.00:1.00 | area= large | maxDets= 10 ] = 0.226
# IoU metric: segm
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=   all | maxDets=100 ] = 0.136
#  Average Precision  (AP) @[  IoU=0.50      | area=   all | maxDets= 10 ] = 0.095
#  Average Precision  (AP) @[  IoU=0.75      | area=   all | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.136
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  1 ] = 0.177
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets=  6 ] = 0.203
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=   all | maxDets= 10 ] = 0.203
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[  IoU=0.00:1.00 | area= large | maxDets= 10 ] = 0.203
# [0.0000] | AR [0.6976] | AP [0.3685]
# [0.0500] | AR [0.6684] | AP [0.3398]
# [0.1000] | AR [0.6600] | AP [0.3366]
# [0.1500] | AR [0.6600] | AP [0.3366]
# [0.2000] | AR [0.6267] | AP [0.3224]
# [0.2500] | AR [0.6184] | AP [0.3172]
# [0.3000] | AR [0.6115] | AP [0.3151]
# [0.3500] | AR [0.5892] | AP [0.2839]
# [0.4000] | AR [0.5892] | AP [0.2839]
# [0.4500] | AR [0.5544] | AP [0.2624]
# [0.5000] | AR [0.5449] | AP [0.2566]
# [0.5500] | AR [0.5061] | AP [0.2341]
# [0.6000] | AR [0.4590] | AP [0.2048]
# [0.6500] | AR [0.4328] | AP [0.1890]
# [0.7000] | AR [0.4328] | AP [0.1890]
# [0.7500] | AR [0.3982] | AP [0.1700]
# [0.8000] | AR [0.3791] | AP [0.1513]
# [0.8500] | AR [0.3512] | AP [0.1357]
# [0.9000] | AR [0.2825] | AP [0.0891]
# [0.9500] | AR [0.1313] | AP [0.0163]
# [1.0000] | AR [0.1188] | AP [0.0140]
# [0.0000] | AR [0.7283] | AP [0.4224]
# [0.0500] | AR [0.6816] | AP [0.3938]
# [0.1000] | AR [0.6816] | AP [0.3938]
# [0.1500] | AR [0.6642] | AP [0.3845]
# [0.2000] | AR [0.6499] | AP [0.3814]
# [0.2500] | AR [0.6060] | AP [0.3634]
# [0.3000] | AR [0.5973] | AP [0.3603]
# [0.3500] | AR [0.5566] | AP [0.3452]
# [0.4000] | AR [0.5423] | AP [0.3429]
# [0.4500] | AR [0.5189] | AP [0.3295]
# [0.5000] | AR [0.4955] | AP [0.2942]
# [0.5500] | AR [0.4868] | AP [0.2911]
# [0.6000] | AR [0.4505] | AP [0.2624]
# [0.6500] | AR [0.4037] | AP [0.2179]
# [0.7000] | AR [0.3622] | AP [0.2021]
# [0.7500] | AR [0.3535] | AP [0.1999]
# [0.8000] | AR [0.2746] | AP [0.1529]
# [0.8500] | AR [0.2482] | AP [0.1233]
# [0.9000] | AR [0.2070] | AP [0.0870]
# [0.9500] | AR [0.1525] | AP [0.0559]
# [1.0000] | AR [0.0931] | AP [0.0285]
# [0.0000] | AR [0.7052] | AP [0.4500]
# [0.0500] | AR [0.4937] | AP [0.3222]
# [0.1000] | AR [0.4937] | AP [0.3222]
# [0.1500] | AR [0.4571] | AP [0.3114]
# [0.2000] | AR [0.4321] | AP [0.3063]
# [0.2500] | AR [0.3766] | AP [0.2648]
# [0.3000] | AR [0.3179] | AP [0.2358]
# [0.3500] | AR [0.2956] | AP [0.2122]
# [0.4000] | AR [0.2567] | AP [0.1809]
# [0.4500] | AR [0.2484] | AP [0.1669]
# [0.5000] | AR [0.2063] | AP [0.1134]
# [0.5500] | AR [0.1813] | AP [0.0908]
# [0.6000] | AR [0.1000] | AP [0.0458]
# [0.6500] | AR [0.0806] | AP [0.0378]
# [0.7000] | AR [0.0556] | AP [0.0130]
# [0.7500] | AR [0.0306] | AP [0.0043]
# [0.8000] | AR [0.0083] | AP [0.0009]
# [0.8500] | AR [0.0000] | AP [0.0000]
# [0.9000] | AR [0.0000] | AP [0.0000]
# [0.9500] | AR [0.0000] | AP [0.0000]
# [1.0000] | AR [0.0000] | AP [0.0000]

# %%
raise StopIteration()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21460/2895586925.py in <module>
# ----> 1 raise StopIteration()
#
# StopIteration:

# %%
# clinical_cond =  "With clincal" if use_clinical else "Without clinical"
# print(f"{clinical_cond} | Average Recall [{test_ar:.4f}] | Average Precision [{test_ap:.4f}]")

# %% [markdown]
# # Plotting

# %%
score_thres= {
    'Enlarged cardiac silhouette': 0.4,
    'Atelectasis': 0.2,
    'Pleural abnormality': 0.2,
    'Consolidation': 0.1,
    'Pulmonary edema': 0.2,
}

# %%
def plot_individual_bbox(
    ann, target, pred, label_idx_to_disease, legend_elements, disease_color_code_map,
):
    n_pred_boxes = len(pred["boxes"])

    fig, axes = plt.subplots(
        1, n_pred_boxes + 2, figsize=((n_pred_boxes + 2) * 10, 10), dpi=80, sharex=True
    )

    fig.legend(handles=legend_elements, loc="upper right")
    img = PIL.Image.open(ann["image_path"]).convert("RGB")

    for ax in axes:
        ax.imshow(img)

    axes[0].set_title(f"REFLACX ({len(target['boxes'].detach().cpu().numpy())})")
    axes[1].set_title(f"Our Radiologists ({len(ann['boxes'].detach().cpu().numpy())})")


    fig.suptitle(f"{ann['image_path']}_({ann['encoding']})")
    for idx, (label, bbox, score) in enumerate(
        zip(
            pred["labels"].detach().cpu().numpy(),
            pred["boxes"].detach().cpu().numpy(),
            pred["scores"].detach().cpu().numpy(),
        )
    ):
        disease = label_idx_to_disease(label)
        c = disease_color_code_map[disease]

        axes[idx + 2].add_patch(
            Rectangle(
                (bbox[0], bbox[1]),
                bbox[2] - bbox[0],
                bbox[3] - bbox[1],
                fill=False,
                color=c,
                linewidth=2,
            )
        )

        axes[idx + 2].set_title(f"Prediction_{disease}")

        axes[idx + 2].text(
            bbox[0],
            bbox[1],
            f"{disease} ({score:.2f})",
            color="black",
            backgroundcolor=c,
        )

    reflacx_recs = []
    for label, bbox in zip(
        target["labels"].detach().cpu().numpy(), target["boxes"].detach().cpu().numpy()
    ):
        disease = label_idx_to_disease(label)
        c = disease_color_code_map[disease]
        reflacx_recs.append(
            Rectangle(
                (bbox[0], bbox[1]),
                bbox[2] - bbox[0],
                bbox[3] - bbox[1],
                fill=False,
                color=c,
                linewidth=2,
            )
        )
        axes[0].text(bbox[0], bbox[1], disease, color="black", backgroundcolor=c)

    for rec in reflacx_recs:
        axes[0].add_patch(rec)

    ann_recs = []
    for label, bbox in zip(
        ann["labels"].detach().cpu().numpy(), ann["boxes"].detach().cpu().numpy()
    ):
        disease = label_idx_to_disease(label)
        c = disease_color_code_map[disease]
        ann_recs.append(
            Rectangle(
                (bbox[0], bbox[1]),
                bbox[2] - bbox[0],
                bbox[3] - bbox[1],
                fill=False,
                color=c,
                linewidth=2,
            )
        )
        axes[1].text(bbox[0], bbox[1], disease, color="black", backgroundcolor=c)

    for rec in ann_recs:
        axes[1].add_patch(rec)

    plt.plot()
    plt.pause(0.01)

    return fig

# %%
model.roi_heads.score_thresh = 0.01 

for ann in radiologists_anns:
    idx= detect_eval_dataset.get_idxs_from_dicom_id(ann['dicom_id'])[0]
    model.eval()
    data = collate_fn([detect_eval_dataset[idx]])
    data = detect_eval_dataset.prepare_input_from_data(data, device)
    target = data[-1]
    pred = model(*data[:-1])
    pred = pred[0]
    pred = pred_thrs_check(pred, detect_eval_dataset, score_thres, device)

    fig = plot_individual_bbox(
        ann,
        target[0],
        pred,
        detect_eval_dataset.label_idx_to_disease,
        legend_elements,
        disease_cmap["solid"],
    )

    save_dir = os.path.join("radiologist_ann_results_separate", "with_clinical"if use_clinical else "without_clinical", ann['encoding'])
    os.makedirs(save_dir, exist_ok=True)
    fig.savefig(os.path.join(save_dir, f"{ann['dicom_id']}.jpg"))

# %%
# def plot_three_bbox(
#     ann, target, pred, label_idx_to_disease, legend_elements, disease_color_code_map
# ):

#     fig, (gt_ax, pred_ax, ann_ax) = plt.subplots(1, 3, figsize=(30, 10), dpi=80, sharex=True)

#     fig.suptitle(f"{target['image_path']}_({ann['encoding']})")

#     fig.legend(handles=legend_elements, loc="upper right")

#     img = PIL.Image.open(target["image_path"]).convert("RGB")

#     gt_ax.imshow(img)
#     gt_ax.set_title(f"REFLACX ({len(target['boxes'].detach().cpu().numpy())})")
#     pred_ax.imshow(img)
#     pred_ax.set_title(f"Predictions ({len(pred['boxes'].detach().cpu().numpy())})")
#     ann_ax.imshow(img)
#     ann_ax.set_title(f"Our Radiologists ({len(ann['boxes'].detach().cpu().numpy())})")

#     # load image
#     gt_recs = []
#     pred_recs = []
#     ann_recs = []

#     for label, bbox, score in zip(
#         pred["labels"].detach().cpu().numpy(),
#         pred["boxes"].detach().cpu().numpy(),
#         pred["scores"].detach().cpu().numpy(),
#     ):
#         disease = label_idx_to_disease(label)
#         c = disease_color_code_map[disease]
#         pred_recs.append(
#             Rectangle(
#                 (bbox[0], bbox[1]),
#                 bbox[2] - bbox[0],
#                 bbox[3] - bbox[1],
#                 fill=False,
#                 color=c,
#                 linewidth=2,
#             )
#         )
#         pred_ax.text(
#             bbox[0],
#             bbox[1],
#             f"{disease} ({score:.2f})",
#             color="black",
#             backgroundcolor=c,
#         )

#     for rec in pred_recs:
#         pred_ax.add_patch(rec)

#     for label, bbox in zip(
#         target["labels"].detach().cpu().numpy(), target["boxes"].detach().cpu().numpy()
#     ):
#         disease = label_idx_to_disease(label)
#         c = disease_color_code_map[disease]
#         gt_recs.append(
#             Rectangle(
#                 (bbox[0], bbox[1]),
#                 bbox[2] - bbox[0],
#                 bbox[3] - bbox[1],
#                 fill=False,
#                 color=c,
#                 linewidth=2,
#             )
#         )
#         gt_ax.text(bbox[0], bbox[1], disease, color="black", backgroundcolor=c)

#     for rec in gt_recs:
#         gt_ax.add_patch(rec)


    
#     for label, bbox in zip(
#         ann["labels"].detach().cpu().numpy(), ann["boxes"].detach().cpu().numpy()
#     ):
#         disease = label_idx_to_disease(label)
#         c = disease_color_code_map[disease]
#         ann_recs.append(
#             Rectangle(
#                 (bbox[0], bbox[1]),
#                 bbox[2] - bbox[0],
#                 bbox[3] - bbox[1],
#                 fill=False,
#                 color=c,
#                 linewidth=2,
#             )
#         )
#         ann_ax.text(bbox[0], bbox[1], disease, color="black", backgroundcolor=c)

#     for rec in ann_recs:
#         ann_ax.add_patch(rec)

#     plt.plot()
#     plt.pause(0.01)

#     return fig

# %%
# model.roi_heads.score_thresh = 0.01 

# for ann in radiologists_anns:
#     idx= detect_eval_dataset.get_idxs_from_dicom_id(ann['dicom_id'])[0]
#     model.eval()
#     data = collate_fn([detect_eval_dataset[idx]])
#     data = detect_eval_dataset.prepare_input_from_data(data, device)
#     target = data[-1]
#     pred = model(*data[:-1])
#     pred = pred[0]
#     pred = pred_thrs_check(pred, detect_eval_dataset, score_thres, device)

#     fig = plot_three_bbox(
#         ann,
#         target[0],
#         pred,
#         detect_eval_dataset.label_idx_to_disease,
#         legend_elements,
#         disease_cmap["solid"],
#     )

#     save_dir = os.path.join("radiologist_ann_results", "with_clinical"if use_clinical else "without_clinical", ann['encoding'])
#     os.makedirs(save_dir, exist_ok=True)
#     fig.savefig(os.path.join(save_dir, f"{ann['dicom_id']}.jpg"))
