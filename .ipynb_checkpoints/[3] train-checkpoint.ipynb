# %%
import os
import torch
import pickle


import pandas as pd
import utils.print as print_f

from datetime import datetime
from data.dataset import REFLACXWithClinicalAndBoundingBoxDataset
from collections import OrderedDict

from utils.transforms import get_transform
from utils.engine import train_one_epoch, evaluate

## Suppress the assignement warning from pandas.
pd.options.mode.chained_assignment = None  # default='warn'

# %%
print("Kernel Alive")
# Out:
# Kernel Alive

# %%
# # load testing.
# import pickle
final_model_path = "epoch199_WithClincal_03-07-2022 18-04-34"
with open(os.path.join("train_hist", f"{final_model_path}.pkl"), 'rb') as f:
    train_hist = pickle.load(f)

# %%
final_model_path = "epoch199_WithClincal_03-07-2022 18-04-34"
os.path.isfile(os.path.join("train_hist", f"{final_model_path}.pkl"))
# Out:
# True

# %% [markdown]
# ### Define your MIMIC folde path here.

# %%
XAMI_MIMIC_PATH = "D:\XAMI-MIMIC"

# %% [markdown]
# ## Checking if GPU is available.
#
# If **GPU (CUDA)** is available, then it will be used. Otherwise, CPU will be applied.

# %%
use_gpu = torch.cuda.is_available()
device = 'cuda' if use_gpu else 'cpu'
print(f"Will be using {device}")
# Out:
# Will be using cuda

# %% [markdown]
# # Initiate datasets and dataloaders
# The batch size is also defined in this section. Since this project will run on single 16GB GTX 3080 (laptop ver.), we can't applied batch size larger than 16.

# %%
## Prepare data
batch_size = 16

train_dataset = REFLACXWithClinicalAndBoundingBoxDataset(
    XAMI_MIMIC_PATH=XAMI_MIMIC_PATH,
    split_str="train",
    transforms=get_transform(train=True),
)

val_dataset = REFLACXWithClinicalAndBoundingBoxDataset(
    XAMI_MIMIC_PATH=XAMI_MIMIC_PATH,
    split_str="val",
    transforms=get_transform(train=False),
)

test_dataset = REFLACXWithClinicalAndBoundingBoxDataset(
    XAMI_MIMIC_PATH=XAMI_MIMIC_PATH,
    split_str="test",
    transforms=get_transform(train=False),
)


train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, collate_fn=REFLACXWithClinicalAndBoundingBoxDataset.collate_fn
)


val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=True, collate_fn=REFLACXWithClinicalAndBoundingBoxDataset.collate_fn
)

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=True, collate_fn=REFLACXWithClinicalAndBoundingBoxDataset.collate_fn
)

# %% [markdown]
# ## Define Model.
#
# We define he models here. Two backbone examples are in the below code section. The MobileNet is a light weight network, and ResNet is heavier, but usually perform better. In our case, the calculation is not the most important factor; therefore, we chose ResNet with feature pyramid networks (FPN) backbone.
#
# To use the pretrained model properly, we aslo fix the first 2 layer of the ResNet backbone.
#
# ** During instantiating the model, we also have to define whether we want to use the clinical data, so the model can adjust for it **

# %%
import torchvision
from models.rcnn import MultimodalFasterRCNN

## Weights of the first 2 layer of the ResNet backbone are fixed.
trainable_backbone_layers = torchvision.models.detection.backbone_utils._validate_trainable_layers(
    True, None, 5, 3
)
backbone = torchvision.models.detection.backbone_utils.resnet_fpn_backbone(
    "resnet50", pretrained=True, trainable_layers=trainable_backbone_layers
)
backbone.out_channels = 256


######################## For MobileNet backbone ########################
# from torchvision.models.detection.faster_rcnn import AnchorGenerator
# backbone = torchvision.models.mobilenet_v2(pretrained=True).features
# backbone.out_channels = 1280
# anchor_generator = AnchorGenerator(
#     sizes=((32, 64, 128, 256, 512),), aspect_ratios=((0.5, 1.0, 2.0),)
# )
# roi_pooler = torchvision.ops.MultiScaleRoIAlign(
#     featmap_names=["0"], output_size=7, sampling_ratio=2
# )
########################################################################

model = MultimodalFasterRCNN(
    backbone,
    num_classes=len(train_dataset.labels_cols) + 1,
    rpn_anchor_generator=None,
    box_roi_pool=None,
    use_clinical=True, # Define whether we use clinical data in our model.
)

# move model to the right device
model.to(device)
# Out:
# MultimodalFasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
#   (gender_emb_layer): Embedding(2, 23)
#   (clinical_convs): ModuleDict(
#     (pool): Sequential(
#       (0): ConvTranspose2d(32, 256, kernel_size=(8, 8), stride=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (0): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (fuse_convs): ModuleDict(
#     (0): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (pool): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %% [markdown]
# # Check how large is this model.

# %%
print(f"Model size: {sum([param.nelement()  for param in model.parameters()]):,}")
# Out:
# Model size: 54,694,171

# %% [markdown]
# ## Define the parameters for training.
#
# We define what are those parameters should be trained. And, also define the optimiser and learning rate scheduler here.

# %%
params = [p for p in model.parameters() if p.requires_grad]

# construct an optimizer
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=3,
                                                gamma=0.1)

# %% [markdown]
# # Train.
#
# We run training here. Number of epochs is defined here. In each epoch, the evaluation of validation dataset will run. At the end, the evaluation will run on test set.

# %%
num_epochs = 200

train_logers = []
val_evaluators = []

start_t = datetime.now()

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_loger = train_one_epoch(model, optimizer, train_dataloader, device, epoch, print_freq=10)
    train_logers.append(train_loger)
    
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    val_evaluator = evaluate(model, val_dataloader, device=device)
    val_evaluators.append(val_evaluator)

end_t = datetime.now()

sec_took = (end_t - start_t).seconds

print_f.print_title(f"| Training Done, start testing! | Training time: [{sec_took}] seconds, Avg time / Epoch: [{sec_took/num_epochs}] seconds")

test_evaluator = evaluate(model, test_dataloader, device=device)
# Out:
# C:\Users\mike8\anaconda3\envs\pytorch\lib\site-packages\torch\functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch: [0]  [ 0/30]  eta: 0:06:58  lr: 0.000177  loss: 2.5297 (2.5297)  loss_classifier: 1.7990 (1.7990)  loss_box_reg: 0.0296 (0.0296)  loss_objectness: 0.6940 (0.6940)  loss_rpn_box_reg: 0.0072 (0.0072)  time: 13.9578  data: 3.0197  max mem: 7968
# Epoch: [0]  [10/30]  eta: 0:01:32  lr: 0.001900  loss: 2.4849 (2.4443)  loss_classifier: 1.7628 (1.7250)  loss_box_reg: 0.0229 (0.0212)  loss_objectness: 0.6929 (0.6917)  loss_rpn_box_reg: 0.0068 (0.0065)  time: 4.6244  data: 2.5131  max mem: 8335
# Epoch: [0]  [20/30]  eta: 0:00:41  lr: 0.003622  loss: 2.0857 (1.7940)  loss_classifier: 1.3804 (1.2176)  loss_box_reg: 0.0229 (0.0313)  loss_objectness: 0.6811 (0.5364)  loss_rpn_box_reg: 0.0068 (0.0086)  time: 3.6770  data: 2.4525  max mem: 8335
# Epoch: [0]  [29/30]  eta: 0:00:04  lr: 0.005000  loss: 0.3924 (1.3539)  loss_classifier: 0.2205 (0.8967)  loss_box_reg: 0.0304 (0.0387)  loss_objectness: 0.1223 (0.4099)  loss_rpn_box_reg: 0.0070 (0.0085)  time: 3.6915  data: 2.4747  max mem: 8335
# Epoch: [0] Total time: 0:02:01 (4.0370 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:20  model_time: 0.5091 (0.5091)  evaluator_time: 0.0320 (0.0320)  time: 2.9687  data: 2.1965  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.5051 (0.4597)  evaluator_time: 0.0160 (0.0179)  time: 2.7621  data: 2.0625  max mem: 8335
# Test: Total time: 0:00:19 (2.7623 s / it)
# Averaged stats: model_time: 0.5051 (0.4597)  evaluator_time: 0.0160 (0.0179)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [1]  [ 0/30]  eta: 0:01:46  lr: 0.005000  loss: 0.2304 (0.2304)  loss_classifier: 0.0893 (0.0893)  loss_box_reg: 0.0526 (0.0526)  loss_objectness: 0.0846 (0.0846)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 3.5513  data: 2.2720  max mem: 8335
# Epoch: [1]  [10/30]  eta: 0:01:12  lr: 0.005000  loss: 0.2176 (0.2141)  loss_classifier: 0.0893 (0.0939)  loss_box_reg: 0.0526 (0.0511)  loss_objectness: 0.0597 (0.0632)  loss_rpn_box_reg: 0.0049 (0.0058)  time: 3.6491  data: 2.3920  max mem: 8335
# Epoch: [1]  [20/30]  eta: 0:00:37  lr: 0.005000  loss: 0.2177 (0.2361)  loss_classifier: 0.0999 (0.1070)  loss_box_reg: 0.0507 (0.0502)  loss_objectness: 0.0630 (0.0727)  loss_rpn_box_reg: 0.0054 (0.0062)  time: 3.7678  data: 2.4968  max mem: 8335
# Epoch: [1]  [29/30]  eta: 0:00:03  lr: 0.005000  loss: 0.2086 (0.2265)  loss_classifier: 0.0962 (0.1009)  loss_box_reg: 0.0401 (0.0483)  loss_objectness: 0.0688 (0.0708)  loss_rpn_box_reg: 0.0051 (0.0065)  time: 3.6626  data: 2.4495  max mem: 8335
# Epoch: [1] Total time: 0:01:49 (3.6629 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:22  model_time: 0.4691 (0.4691)  evaluator_time: 0.0240 (0.0240)  time: 3.2007  data: 2.2985  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4691 (0.4268)  evaluator_time: 0.0140 (0.0156)  time: 2.6850  data: 1.9977  max mem: 8335
# Test: Total time: 0:00:18 (2.6853 s / it)
# Averaged stats: model_time: 0.4691 (0.4268)  evaluator_time: 0.0140 (0.0156)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [ 0/30]  eta: 0:01:41  lr: 0.005000  loss: 0.2062 (0.2062)  loss_classifier: 0.0910 (0.0910)  loss_box_reg: 0.0501 (0.0501)  loss_objectness: 0.0593 (0.0593)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 3.3878  data: 2.1455  max mem: 8335
# Epoch: [2]  [10/30]  eta: 0:01:09  lr: 0.005000  loss: 0.2034 (0.2164)  loss_classifier: 0.0901 (0.0953)  loss_box_reg: 0.0512 (0.0569)  loss_objectness: 0.0593 (0.0587)  loss_rpn_box_reg: 0.0058 (0.0056)  time: 3.4831  data: 2.2384  max mem: 8335
# Epoch: [2]  [20/30]  eta: 0:00:35  lr: 0.005000  loss: 0.2451 (0.2394)  loss_classifier: 0.0965 (0.1073)  loss_box_reg: 0.0584 (0.0672)  loss_objectness: 0.0601 (0.0586)  loss_rpn_box_reg: 0.0059 (0.0063)  time: 3.5194  data: 2.2663  max mem: 8335
# Epoch: [2]  [29/30]  eta: 0:00:03  lr: 0.005000  loss: 0.2757 (0.2397)  loss_classifier: 0.1259 (0.1091)  loss_box_reg: 0.0799 (0.0693)  loss_objectness: 0.0525 (0.0553)  loss_rpn_box_reg: 0.0054 (0.0060)  time: 3.4199  data: 2.2145  max mem: 8335
# Epoch: [2] Total time: 0:01:43 (3.4399 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:22  model_time: 0.4781 (0.4781)  evaluator_time: 0.0240 (0.0240)  time: 3.2317  data: 2.2525  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4901 (0.4438)  evaluator_time: 0.0110 (0.0146)  time: 2.7326  data: 2.0166  max mem: 8335
# Test: Total time: 0:00:19 (2.7328 s / it)
# Averaged stats: model_time: 0.4901 (0.4438)  evaluator_time: 0.0110 (0.0146)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.032
# Epoch: [3]  [ 0/30]  eta: 0:01:44  lr: 0.000500  loss: 0.2802 (0.2802)  loss_classifier: 0.1391 (0.1391)  loss_box_reg: 0.0799 (0.0799)  loss_objectness: 0.0554 (0.0554)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 3.4678  data: 2.2175  max mem: 8335
# Epoch: [3]  [10/30]  eta: 0:01:08  lr: 0.000500  loss: 0.2802 (0.2886)  loss_classifier: 0.1348 (0.1388)  loss_box_reg: 0.0870 (0.0913)  loss_objectness: 0.0515 (0.0521)  loss_rpn_box_reg: 0.0061 (0.0064)  time: 3.4090  data: 2.1842  max mem: 8335
# Epoch: [3]  [20/30]  eta: 0:00:34  lr: 0.000500  loss: 0.2295 (0.2548)  loss_classifier: 0.1127 (0.1223)  loss_box_reg: 0.0740 (0.0792)  loss_objectness: 0.0458 (0.0482)  loss_rpn_box_reg: 0.0048 (0.0052)  time: 3.4632  data: 2.2237  max mem: 8335
# Epoch: [3]  [29/30]  eta: 0:00:03  lr: 0.000500  loss: 0.2473 (0.2647)  loss_classifier: 0.1204 (0.1254)  loss_box_reg: 0.0823 (0.0827)  loss_objectness: 0.0476 (0.0507)  loss_rpn_box_reg: 0.0045 (0.0058)  time: 3.3668  data: 2.1653  max mem: 8335
# Epoch: [3] Total time: 0:01:41 (3.3812 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:22  model_time: 0.4851 (0.4851)  evaluator_time: 0.0270 (0.0270)  time: 3.2147  data: 2.3015  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4851 (0.4391)  evaluator_time: 0.0160 (0.0166)  time: 2.7033  data: 2.0046  max mem: 8335
# Test: Total time: 0:00:18 (2.7035 s / it)
# Averaged stats: model_time: 0.4851 (0.4391)  evaluator_time: 0.0160 (0.0166)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
# Epoch: [4]  [ 0/30]  eta: 0:01:41  lr: 0.000500  loss: 0.1483 (0.1483)  loss_classifier: 0.0613 (0.0613)  loss_box_reg: 0.0276 (0.0276)  loss_objectness: 0.0497 (0.0497)  loss_rpn_box_reg: 0.0097 (0.0097)  time: 3.3918  data: 2.1385  max mem: 8335
# Epoch: [4]  [10/30]  eta: 0:01:08  lr: 0.000500  loss: 0.2525 (0.2829)  loss_classifier: 0.1185 (0.1310)  loss_box_reg: 0.0893 (0.0907)  loss_objectness: 0.0497 (0.0533)  loss_rpn_box_reg: 0.0069 (0.0078)  time: 3.4294  data: 2.1872  max mem: 8335
# Epoch: [4]  [20/30]  eta: 0:00:34  lr: 0.000500  loss: 0.2410 (0.2585)  loss_classifier: 0.1136 (0.1206)  loss_box_reg: 0.0732 (0.0821)  loss_objectness: 0.0463 (0.0495)  loss_rpn_box_reg: 0.0055 (0.0063)  time: 3.4562  data: 2.2113  max mem: 8335
# Epoch: [4]  [29/30]  eta: 0:00:03  lr: 0.000500  loss: 0.2233 (0.2533)  loss_classifier: 0.1056 (0.1185)  loss_box_reg: 0.0716 (0.0797)  loss_objectness: 0.0412 (0.0493)  loss_rpn_box_reg: 0.0038 (0.0058)  time: 3.3388  data: 2.1422  max mem: 8335
# Epoch: [4] Total time: 0:01:41 (3.3681 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:23  model_time: 0.4831 (0.4831)  evaluator_time: 0.0240 (0.0240)  time: 3.3428  data: 2.3885  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4801 (0.4347)  evaluator_time: 0.0210 (0.0190)  time: 2.7622  data: 2.0503  max mem: 8335
# Test: Total time: 0:00:19 (2.7625 s / it)
# Averaged stats: model_time: 0.4801 (0.4347)  evaluator_time: 0.0210 (0.0190)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.046
# Epoch: [5]  [ 0/30]  eta: 0:01:40  lr: 0.000500  loss: 0.2150 (0.2150)  loss_classifier: 0.1095 (0.1095)  loss_box_reg: 0.0655 (0.0655)  loss_objectness: 0.0357 (0.0357)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 3.3568  data: 2.1125  max mem: 8335
# Epoch: [5]  [10/30]  eta: 0:01:09  lr: 0.000500  loss: 0.2352 (0.2470)  loss_classifier: 0.1108 (0.1184)  loss_box_reg: 0.0784 (0.0818)  loss_objectness: 0.0412 (0.0421)  loss_rpn_box_reg: 0.0040 (0.0047)  time: 3.4985  data: 2.2414  max mem: 8335
# Epoch: [5]  [20/30]  eta: 0:00:35  lr: 0.000500  loss: 0.2352 (0.2566)  loss_classifier: 0.1075 (0.1205)  loss_box_reg: 0.0775 (0.0822)  loss_objectness: 0.0488 (0.0480)  loss_rpn_box_reg: 0.0052 (0.0059)  time: 3.5247  data: 2.2680  max mem: 8335
# Epoch: [5]  [29/30]  eta: 0:00:03  lr: 0.000500  loss: 0.2484 (0.2620)  loss_classifier: 0.1075 (0.1226)  loss_box_reg: 0.0775 (0.0835)  loss_objectness: 0.0489 (0.0499)  loss_rpn_box_reg: 0.0061 (0.0060)  time: 3.4010  data: 2.1861  max mem: 8335
# Epoch: [5] Total time: 0:01:43 (3.4341 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:21  model_time: 0.4651 (0.4651)  evaluator_time: 0.0240 (0.0240)  time: 3.0647  data: 2.1445  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4791 (0.4341)  evaluator_time: 0.0210 (0.0176)  time: 2.6403  data: 1.9404  max mem: 8335
# Test: Total time: 0:00:18 (2.6405 s / it)
# Averaged stats: model_time: 0.4791 (0.4341)  evaluator_time: 0.0210 (0.0176)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.051
# Epoch: [6]  [ 0/30]  eta: 0:01:38  lr: 0.000050  loss: 0.2831 (0.2831)  loss_classifier: 0.1283 (0.1283)  loss_box_reg: 0.0671 (0.0671)  loss_objectness: 0.0800 (0.0800)  loss_rpn_box_reg: 0.0077 (0.0077)  time: 3.2883  data: 2.0755  max mem: 8335
# Epoch: [6]  [10/30]  eta: 0:01:06  lr: 0.000050  loss: 0.2543 (0.2571)  loss_classifier: 0.1179 (0.1212)  loss_box_reg: 0.0729 (0.0805)  loss_objectness: 0.0471 (0.0494)  loss_rpn_box_reg: 0.0057 (0.0060)  time: 3.3152  data: 2.0879  max mem: 8335
# Epoch: [6]  [20/30]  eta: 0:00:33  lr: 0.000050  loss: 0.2411 (0.2448)  loss_classifier: 0.1083 (0.1139)  loss_box_reg: 0.0729 (0.0758)  loss_objectness: 0.0471 (0.0490)  loss_rpn_box_reg: 0.0047 (0.0060)  time: 3.3424  data: 2.1077  max mem: 8335
# Epoch: [6]  [29/30]  eta: 0:00:03  lr: 0.000050  loss: 0.2497 (0.2602)  loss_classifier: 0.1123 (0.1232)  loss_box_reg: 0.0734 (0.0828)  loss_objectness: 0.0458 (0.0483)  loss_rpn_box_reg: 0.0046 (0.0059)  time: 3.2461  data: 2.0470  max mem: 8335
# Epoch: [6] Total time: 0:01:38 (3.2708 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:21  model_time: 0.4661 (0.4661)  evaluator_time: 0.0210 (0.0210)  time: 3.0967  data: 2.1495  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4861 (0.4370)  evaluator_time: 0.0190 (0.0334)  time: 2.6742  data: 1.9510  max mem: 8335
# Test: Total time: 0:00:18 (2.6743 s / it)
# Averaged stats: model_time: 0.4861 (0.4370)  evaluator_time: 0.0190 (0.0334)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.044
# Epoch: [7]  [ 0/30]  eta: 0:02:07  lr: 0.000050  loss: 0.2279 (0.2279)  loss_classifier: 0.1098 (0.1098)  loss_box_reg: 0.0781 (0.0781)  loss_objectness: 0.0360 (0.0360)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 4.2458  data: 2.9084  max mem: 8335
# Epoch: [7]  [10/30]  eta: 0:01:27  lr: 0.000050  loss: 0.2279 (0.2413)  loss_classifier: 0.1123 (0.1168)  loss_box_reg: 0.0781 (0.0777)  loss_objectness: 0.0419 (0.0424)  loss_rpn_box_reg: 0.0041 (0.0044)  time: 4.3691  data: 3.0560  max mem: 8335
# Epoch: [7]  [20/30]  eta: 0:00:40  lr: 0.000050  loss: 0.2521 (0.2477)  loss_classifier: 0.1123 (0.1161)  loss_box_reg: 0.0738 (0.0777)  loss_objectness: 0.0448 (0.0480)  loss_rpn_box_reg: 0.0047 (0.0059)  time: 4.0753  data: 2.8213  max mem: 8335
# Epoch: [7]  [29/30]  eta: 0:00:03  lr: 0.000050  loss: 0.2521 (0.2539)  loss_classifier: 0.1134 (0.1192)  loss_box_reg: 0.0757 (0.0815)  loss_objectness: 0.0455 (0.0474)  loss_rpn_box_reg: 0.0059 (0.0058)  time: 3.6822  data: 2.5256  max mem: 8335
# Epoch: [7] Total time: 0:01:57 (3.9188 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:21  model_time: 0.4571 (0.4571)  evaluator_time: 0.0260 (0.0260)  time: 3.1087  data: 2.2255  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4801 (0.4350)  evaluator_time: 0.0220 (0.0190)  time: 2.7620  data: 2.0675  max mem: 8335
# Test: Total time: 0:00:19 (2.7621 s / it)
# Averaged stats: model_time: 0.4801 (0.4350)  evaluator_time: 0.0220 (0.0190)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.049
# Epoch: [8]  [ 0/30]  eta: 0:01:46  lr: 0.000050  loss: 0.2277 (0.2277)  loss_classifier: 0.0912 (0.0912)  loss_box_reg: 0.0544 (0.0544)  loss_objectness: 0.0666 (0.0666)  loss_rpn_box_reg: 0.0154 (0.0154)  time: 3.5603  data: 2.3655  max mem: 8335
# Epoch: [8]  [10/30]  eta: 0:01:12  lr: 0.000050  loss: 0.2268 (0.2264)  loss_classifier: 0.1009 (0.1050)  loss_box_reg: 0.0673 (0.0708)  loss_objectness: 0.0439 (0.0450)  loss_rpn_box_reg: 0.0043 (0.0055)  time: 3.6158  data: 2.4335  max mem: 8335
# Epoch: [8]  [20/30]  eta: 0:00:36  lr: 0.000050  loss: 0.2574 (0.2533)  loss_classifier: 0.1207 (0.1182)  loss_box_reg: 0.0804 (0.0803)  loss_objectness: 0.0439 (0.0488)  loss_rpn_box_reg: 0.0051 (0.0060)  time: 3.6189  data: 2.4347  max mem: 8335
# Epoch: [8]  [29/30]  eta: 0:00:03  lr: 0.000050  loss: 0.2745 (0.2565)  loss_classifier: 0.1320 (0.1204)  loss_box_reg: 0.0899 (0.0823)  loss_objectness: 0.0446 (0.0479)  loss_rpn_box_reg: 0.0054 (0.0059)  time: 3.4940  data: 2.3469  max mem: 8335
# Epoch: [8] Total time: 0:01:46 (3.5355 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:20  model_time: 0.4511 (0.4511)  evaluator_time: 0.0240 (0.0240)  time: 2.9447  data: 2.1085  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4511 (0.4264)  evaluator_time: 0.0180 (0.0157)  time: 2.6633  data: 1.9899  max mem: 8335
# Test: Total time: 0:00:18 (2.6635 s / it)
# Averaged stats: model_time: 0.4511 (0.4264)  evaluator_time: 0.0180 (0.0157)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [9]  [ 0/30]  eta: 0:01:40  lr: 0.000005  loss: 0.2385 (0.2385)  loss_classifier: 0.1153 (0.1153)  loss_box_reg: 0.0728 (0.0728)  loss_objectness: 0.0471 (0.0471)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 3.3544  data: 2.2015  max mem: 8335
# Epoch: [9]  [10/30]  eta: 0:01:09  lr: 0.000005  loss: 0.2597 (0.2722)  loss_classifier: 0.1217 (0.1283)  loss_box_reg: 0.0765 (0.0869)  loss_objectness: 0.0505 (0.0511)  loss_rpn_box_reg: 0.0048 (0.0059)  time: 3.4946  data: 2.3173  max mem: 8335
# Epoch: [9]  [20/30]  eta: 0:00:34  lr: 0.000005  loss: 0.2566 (0.2490)  loss_classifier: 0.1211 (0.1171)  loss_box_reg: 0.0759 (0.0792)  loss_objectness: 0.0424 (0.0469)  loss_rpn_box_reg: 0.0053 (0.0058)  time: 3.4869  data: 2.3054  max mem: 8335
# Epoch: [9]  [29/30]  eta: 0:00:03  lr: 0.000005  loss: 0.2566 (0.2586)  loss_classifier: 0.1172 (0.1208)  loss_box_reg: 0.0758 (0.0837)  loss_objectness: 0.0424 (0.0481)  loss_rpn_box_reg: 0.0053 (0.0060)  time: 3.3437  data: 2.2013  max mem: 8335
# Epoch: [9] Total time: 0:01:41 (3.3926 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:20  model_time: 0.4411 (0.4411)  evaluator_time: 0.0210 (0.0210)  time: 2.9527  data: 2.1385  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4461 (0.4185)  evaluator_time: 0.0180 (0.0150)  time: 2.6382  data: 1.9761  max mem: 8335
# Test: Total time: 0:00:18 (2.6383 s / it)
# Averaged stats: model_time: 0.4461 (0.4185)  evaluator_time: 0.0180 (0.0150)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [10]  [ 0/30]  eta: 0:01:35  lr: 0.000005  loss: 0.2483 (0.2483)  loss_classifier: 0.1187 (0.1187)  loss_box_reg: 0.0793 (0.0793)  loss_objectness: 0.0437 (0.0437)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 3.1673  data: 2.0025  max mem: 8335
# Epoch: [10]  [10/30]  eta: 0:01:07  lr: 0.000005  loss: 0.2380 (0.2607)  loss_classifier: 0.1121 (0.1205)  loss_box_reg: 0.0733 (0.0842)  loss_objectness: 0.0457 (0.0491)  loss_rpn_box_reg: 0.0057 (0.0069)  time: 3.3892  data: 2.1937  max mem: 8335
# Epoch: [10]  [20/30]  eta: 0:00:34  lr: 0.000005  loss: 0.2380 (0.2576)  loss_classifier: 0.1121 (0.1206)  loss_box_reg: 0.0733 (0.0821)  loss_objectness: 0.0458 (0.0487)  loss_rpn_box_reg: 0.0056 (0.0062)  time: 3.4249  data: 2.2365  max mem: 8335
# Epoch: [10]  [29/30]  eta: 0:00:03  lr: 0.000005  loss: 0.2504 (0.2594)  loss_classifier: 0.1213 (0.1215)  loss_box_reg: 0.0785 (0.0836)  loss_objectness: 0.0458 (0.0483)  loss_rpn_box_reg: 0.0048 (0.0060)  time: 3.3161  data: 2.1786  max mem: 8335
# Epoch: [10] Total time: 0:01:40 (3.3344 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:21  model_time: 0.4391 (0.4391)  evaluator_time: 0.0210 (0.0210)  time: 3.0447  data: 2.1245  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4811 (0.4334)  evaluator_time: 0.0190 (0.0174)  time: 2.6765  data: 1.9819  max mem: 8335
# Test: Total time: 0:00:18 (2.6766 s / it)
# Averaged stats: model_time: 0.4811 (0.4334)  evaluator_time: 0.0190 (0.0174)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [11]  [ 0/30]  eta: 0:01:34  lr: 0.000005  loss: 0.2407 (0.2407)  loss_classifier: 0.1100 (0.1100)  loss_box_reg: 0.0794 (0.0794)  loss_objectness: 0.0467 (0.0467)  loss_rpn_box_reg: 0.0047 (0.0047)  time: 3.1467  data: 1.9805  max mem: 8335
# Epoch: [11]  [10/30]  eta: 0:01:07  lr: 0.000005  loss: 0.2407 (0.2348)  loss_classifier: 0.1092 (0.1079)  loss_box_reg: 0.0781 (0.0740)  loss_objectness: 0.0470 (0.0474)  loss_rpn_box_reg: 0.0047 (0.0055)  time: 3.3569  data: 2.1892  max mem: 8335
# Epoch: [11]  [20/30]  eta: 0:00:33  lr: 0.000005  loss: 0.2426 (0.2477)  loss_classifier: 0.1080 (0.1146)  loss_box_reg: 0.0756 (0.0773)  loss_objectness: 0.0496 (0.0494)  loss_rpn_box_reg: 0.0055 (0.0064)  time: 3.4060  data: 2.2310  max mem: 8335
# Epoch: [11]  [29/30]  eta: 0:00:03  lr: 0.000005  loss: 0.2544 (0.2551)  loss_classifier: 0.1147 (0.1194)  loss_box_reg: 0.0857 (0.0820)  loss_objectness: 0.0460 (0.0478)  loss_rpn_box_reg: 0.0054 (0.0058)  time: 3.2794  data: 2.1427  max mem: 8335
# Epoch: [11] Total time: 0:01:39 (3.3033 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:20  model_time: 0.4411 (0.4411)  evaluator_time: 0.0210 (0.0210)  time: 2.9527  data: 2.0905  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4421 (0.4088)  evaluator_time: 0.0180 (0.0151)  time: 2.6177  data: 1.9593  max mem: 8335
# Test: Total time: 0:00:18 (2.6180 s / it)
# Averaged stats: model_time: 0.4421 (0.4088)  evaluator_time: 0.0180 (0.0151)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [12]  [ 0/30]  eta: 0:01:39  lr: 0.000001  loss: 0.2498 (0.2498)  loss_classifier: 0.1216 (0.1216)  loss_box_reg: 0.0938 (0.0938)  loss_objectness: 0.0308 (0.0308)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 3.3277  data: 2.1775  max mem: 8335
# Epoch: [12]  [10/30]  eta: 0:01:09  lr: 0.000001  loss: 0.2675 (0.2658)  loss_classifier: 0.1216 (0.1245)  loss_box_reg: 0.0938 (0.0905)  loss_objectness: 0.0456 (0.0452)  loss_rpn_box_reg: 0.0059 (0.0057)  time: 3.4638  data: 2.2892  max mem: 8335
# Epoch: [12]  [20/30]  eta: 0:00:35  lr: 0.000001  loss: 0.2708 (0.2553)  loss_classifier: 0.1198 (0.1183)  loss_box_reg: 0.0873 (0.0829)  loss_objectness: 0.0464 (0.0478)  loss_rpn_box_reg: 0.0055 (0.0063)  time: 3.5114  data: 2.3329  max mem: 8335
# Epoch: [12]  [29/30]  eta: 0:00:03  lr: 0.000001  loss: 0.2543 (0.2527)  loss_classifier: 0.1170 (0.1185)  loss_box_reg: 0.0720 (0.0812)  loss_objectness: 0.0438 (0.0473)  loss_rpn_box_reg: 0.0039 (0.0058)  time: 3.4275  data: 2.2878  max mem: 8335
# Epoch: [12] Total time: 0:01:43 (3.4401 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:22  model_time: 0.4441 (0.4441)  evaluator_time: 0.0200 (0.0200)  time: 3.1667  data: 2.2585  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4981 (0.4357)  evaluator_time: 0.0180 (0.0147)  time: 2.7229  data: 2.0295  max mem: 8335
# Test: Total time: 0:00:19 (2.7233 s / it)
# Averaged stats: model_time: 0.4981 (0.4357)  evaluator_time: 0.0180 (0.0147)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [13]  [ 0/30]  eta: 0:01:40  lr: 0.000001  loss: 0.2766 (0.2766)  loss_classifier: 0.1326 (0.1326)  loss_box_reg: 0.0889 (0.0889)  loss_objectness: 0.0508 (0.0508)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 3.3638  data: 2.2025  max mem: 8335
# Epoch: [13]  [10/30]  eta: 0:01:10  lr: 0.000001  loss: 0.2411 (0.2418)  loss_classifier: 0.1133 (0.1140)  loss_box_reg: 0.0787 (0.0754)  loss_objectness: 0.0453 (0.0473)  loss_rpn_box_reg: 0.0045 (0.0051)  time: 3.5411  data: 2.3634  max mem: 8335
# Epoch: [13]  [20/30]  eta: 0:00:35  lr: 0.000001  loss: 0.2660 (0.2643)  loss_classifier: 0.1220 (0.1225)  loss_box_reg: 0.0811 (0.0843)  loss_objectness: 0.0494 (0.0511)  loss_rpn_box_reg: 0.0049 (0.0064)  time: 3.5457  data: 2.3596  max mem: 8335
# Epoch: [13]  [29/30]  eta: 0:00:03  lr: 0.000001  loss: 0.2290 (0.2540)  loss_classifier: 0.1137 (0.1193)  loss_box_reg: 0.0755 (0.0814)  loss_objectness: 0.0446 (0.0475)  loss_rpn_box_reg: 0.0046 (0.0058)  time: 3.3703  data: 2.2245  max mem: 8335
# Epoch: [13] Total time: 0:01:42 (3.4309 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:22  model_time: 0.4401 (0.4401)  evaluator_time: 0.0170 (0.0170)  time: 3.2057  data: 2.3125  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4441 (0.4124)  evaluator_time: 0.0110 (0.0140)  time: 2.6756  data: 2.0132  max mem: 8335
# Test: Total time: 0:00:18 (2.6759 s / it)
# Averaged stats: model_time: 0.4441 (0.4124)  evaluator_time: 0.0110 (0.0140)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [14]  [ 0/30]  eta: 0:01:35  lr: 0.000001  loss: 0.1961 (0.1961)  loss_classifier: 0.0937 (0.0937)  loss_box_reg: 0.0598 (0.0598)  loss_objectness: 0.0385 (0.0385)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 3.1715  data: 2.0295  max mem: 8335
# Epoch: [14]  [10/30]  eta: 0:01:07  lr: 0.000001  loss: 0.2295 (0.2364)  loss_classifier: 0.0957 (0.1109)  loss_box_reg: 0.0738 (0.0752)  loss_objectness: 0.0447 (0.0451)  loss_rpn_box_reg: 0.0044 (0.0052)  time: 3.3722  data: 2.1974  max mem: 8335
# Epoch: [14]  [20/30]  eta: 0:00:33  lr: 0.000001  loss: 0.2434 (0.2447)  loss_classifier: 0.1181 (0.1153)  loss_box_reg: 0.0766 (0.0778)  loss_objectness: 0.0447 (0.0462)  loss_rpn_box_reg: 0.0047 (0.0053)  time: 3.3764  data: 2.2013  max mem: 8335
# Epoch: [14]  [29/30]  eta: 0:00:03  lr: 0.000001  loss: 0.2600 (0.2600)  loss_classifier: 0.1200 (0.1216)  loss_box_reg: 0.0847 (0.0841)  loss_objectness: 0.0472 (0.0483)  loss_rpn_box_reg: 0.0051 (0.0060)  time: 3.2433  data: 2.1031  max mem: 8335
# Epoch: [14] Total time: 0:01:38 (3.2865 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:21  model_time: 0.4431 (0.4431)  evaluator_time: 0.0220 (0.0220)  time: 3.0157  data: 2.1085  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4581 (0.4237)  evaluator_time: 0.0190 (0.0164)  time: 2.6623  data: 1.9842  max mem: 8335
# Test: Total time: 0:00:18 (2.6625 s / it)
# Averaged stats: model_time: 0.4581 (0.4237)  evaluator_time: 0.0190 (0.0164)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [15]  [ 0/30]  eta: 0:01:36  lr: 0.000000  loss: 0.3006 (0.3006)  loss_classifier: 0.1372 (0.1372)  loss_box_reg: 0.1057 (0.1057)  loss_objectness: 0.0498 (0.0498)  loss_rpn_box_reg: 0.0079 (0.0079)  time: 3.2237  data: 2.0215  max mem: 8335
# Epoch: [15]  [10/30]  eta: 0:01:07  lr: 0.000000  loss: 0.2491 (0.2523)  loss_classifier: 0.1202 (0.1204)  loss_box_reg: 0.0750 (0.0814)  loss_objectness: 0.0492 (0.0455)  loss_rpn_box_reg: 0.0048 (0.0051)  time: 3.3915  data: 2.2129  max mem: 8335
# Epoch: [15]  [20/30]  eta: 0:00:33  lr: 0.000000  loss: 0.2316 (0.2576)  loss_classifier: 0.1000 (0.1218)  loss_box_reg: 0.0694 (0.0829)  loss_objectness: 0.0491 (0.0472)  loss_rpn_box_reg: 0.0048 (0.0057)  time: 3.4018  data: 2.2274  max mem: 8335
# Epoch: [15]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2326 (0.2538)  loss_classifier: 0.1098 (0.1188)  loss_box_reg: 0.0737 (0.0811)  loss_objectness: 0.0502 (0.0480)  loss_rpn_box_reg: 0.0062 (0.0059)  time: 3.2957  data: 2.1579  max mem: 8335
# Epoch: [15] Total time: 0:01:39 (3.3305 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:21  model_time: 0.4441 (0.4441)  evaluator_time: 0.0190 (0.0190)  time: 3.0807  data: 2.2125  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4441 (0.4107)  evaluator_time: 0.0190 (0.0150)  time: 2.6244  data: 1.9645  max mem: 8335
# Test: Total time: 0:00:18 (2.6245 s / it)
# Averaged stats: model_time: 0.4441 (0.4107)  evaluator_time: 0.0190 (0.0150)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [16]  [ 0/30]  eta: 0:01:39  lr: 0.000000  loss: 0.2196 (0.2196)  loss_classifier: 0.1024 (0.1024)  loss_box_reg: 0.0661 (0.0661)  loss_objectness: 0.0463 (0.0463)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 3.3316  data: 2.1645  max mem: 8335
# Epoch: [16]  [10/30]  eta: 0:01:07  lr: 0.000000  loss: 0.2407 (0.2499)  loss_classifier: 0.1096 (0.1150)  loss_box_reg: 0.0662 (0.0740)  loss_objectness: 0.0575 (0.0538)  loss_rpn_box_reg: 0.0064 (0.0072)  time: 3.3986  data: 2.2181  max mem: 8335
# Epoch: [16]  [20/30]  eta: 0:00:34  lr: 0.000000  loss: 0.2821 (0.2722)  loss_classifier: 0.1308 (0.1276)  loss_box_reg: 0.0955 (0.0879)  loss_objectness: 0.0521 (0.0506)  loss_rpn_box_reg: 0.0054 (0.0062)  time: 3.4227  data: 2.2432  max mem: 8335
# Epoch: [16]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2483 (0.2585)  loss_classifier: 0.1137 (0.1213)  loss_box_reg: 0.0891 (0.0835)  loss_objectness: 0.0415 (0.0478)  loss_rpn_box_reg: 0.0051 (0.0059)  time: 3.3494  data: 2.2090  max mem: 8335
# Epoch: [16] Total time: 0:01:40 (3.3639 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:22  model_time: 0.4401 (0.4401)  evaluator_time: 0.0230 (0.0230)  time: 3.2097  data: 2.3045  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4431 (0.4127)  evaluator_time: 0.0180 (0.0173)  time: 2.7959  data: 2.1233  max mem: 8335
# Test: Total time: 0:00:19 (2.7962 s / it)
# Averaged stats: model_time: 0.4431 (0.4127)  evaluator_time: 0.0180 (0.0173)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [17]  [ 0/30]  eta: 0:01:42  lr: 0.000000  loss: 0.1450 (0.1450)  loss_classifier: 0.0751 (0.0751)  loss_box_reg: 0.0464 (0.0464)  loss_objectness: 0.0225 (0.0225)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 3.4298  data: 2.2185  max mem: 8335
# Epoch: [17]  [10/30]  eta: 0:01:08  lr: 0.000000  loss: 0.2761 (0.2714)  loss_classifier: 0.1332 (0.1266)  loss_box_reg: 0.0945 (0.0876)  loss_objectness: 0.0538 (0.0508)  loss_rpn_box_reg: 0.0059 (0.0065)  time: 3.4103  data: 2.2348  max mem: 8335
# Epoch: [17]  [20/30]  eta: 0:00:33  lr: 0.000000  loss: 0.2759 (0.2686)  loss_classifier: 0.1298 (0.1263)  loss_box_reg: 0.0896 (0.0862)  loss_objectness: 0.0538 (0.0502)  loss_rpn_box_reg: 0.0054 (0.0059)  time: 3.3807  data: 2.2014  max mem: 8335
# Epoch: [17]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2293 (0.2580)  loss_classifier: 0.1079 (0.1214)  loss_box_reg: 0.0740 (0.0831)  loss_objectness: 0.0398 (0.0477)  loss_rpn_box_reg: 0.0045 (0.0058)  time: 3.2566  data: 2.1151  max mem: 8335
# Epoch: [17] Total time: 0:01:39 (3.3069 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4361 (0.4361)  evaluator_time: 0.0180 (0.0180)  time: 2.8326  data: 2.0215  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4521 (0.4200)  evaluator_time: 0.0170 (0.0137)  time: 2.5679  data: 1.9071  max mem: 8335
# Test: Total time: 0:00:17 (2.5680 s / it)
# Averaged stats: model_time: 0.4521 (0.4200)  evaluator_time: 0.0170 (0.0137)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [18]  [ 0/30]  eta: 0:01:41  lr: 0.000000  loss: 0.3189 (0.3189)  loss_classifier: 0.1448 (0.1448)  loss_box_reg: 0.0977 (0.0977)  loss_objectness: 0.0692 (0.0692)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 3.3745  data: 2.2175  max mem: 8335
# Epoch: [18]  [10/30]  eta: 0:01:07  lr: 0.000000  loss: 0.2488 (0.2649)  loss_classifier: 0.1141 (0.1232)  loss_box_reg: 0.0928 (0.0853)  loss_objectness: 0.0510 (0.0509)  loss_rpn_box_reg: 0.0060 (0.0055)  time: 3.3523  data: 2.1665  max mem: 8335
# Epoch: [18]  [20/30]  eta: 0:00:32  lr: 0.000000  loss: 0.2464 (0.2738)  loss_classifier: 0.1141 (0.1268)  loss_box_reg: 0.0774 (0.0882)  loss_objectness: 0.0486 (0.0523)  loss_rpn_box_reg: 0.0051 (0.0065)  time: 3.2917  data: 2.1071  max mem: 8335
# Epoch: [18]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2429 (0.2594)  loss_classifier: 0.1153 (0.1217)  loss_box_reg: 0.0752 (0.0835)  loss_objectness: 0.0470 (0.0482)  loss_rpn_box_reg: 0.0051 (0.0059)  time: 3.1187  data: 1.9818  max mem: 8335
# Epoch: [18] Total time: 0:01:35 (3.1954 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:20  model_time: 0.4361 (0.4361)  evaluator_time: 0.0190 (0.0190)  time: 2.9027  data: 2.0315  max mem: 8335
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4411 (0.4052)  evaluator_time: 0.0170 (0.0151)  time: 2.5249  data: 1.8700  max mem: 8335
# Test: Total time: 0:00:17 (2.5250 s / it)
# Averaged stats: model_time: 0.4411 (0.4052)  evaluator_time: 0.0170 (0.0151)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [19]  [ 0/30]  eta: 0:01:38  lr: 0.000000  loss: 0.2255 (0.2255)  loss_classifier: 0.1079 (0.1079)  loss_box_reg: 0.0782 (0.0782)  loss_objectness: 0.0352 (0.0352)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 3.2698  data: 2.1025  max mem: 8335
# ...
# Epoch: [194]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2258 (0.2555)  loss_classifier: 0.1057 (0.1194)  loss_box_reg: 0.0686 (0.0820)  loss_objectness: 0.0464 (0.0482)  loss_rpn_box_reg: 0.0048 (0.0059)  time: 3.0426  data: 1.9163  max mem: 8337
# Epoch: [194] Total time: 0:01:32 (3.0744 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4391 (0.4391)  evaluator_time: 0.0200 (0.0200)  time: 2.8036  data: 1.9434  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4411 (0.4094)  evaluator_time: 0.0180 (0.0163)  time: 2.4123  data: 1.7567  max mem: 8337
# Test: Total time: 0:00:16 (2.4124 s / it)
# Averaged stats: model_time: 0.4411 (0.4094)  evaluator_time: 0.0180 (0.0163)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [195]  [ 0/30]  eta: 0:01:34  lr: 0.000000  loss: 0.3183 (0.3183)  loss_classifier: 0.1422 (0.1422)  loss_box_reg: 0.1004 (0.1004)  loss_objectness: 0.0649 (0.0649)  loss_rpn_box_reg: 0.0109 (0.0109)  time: 3.1495  data: 1.9794  max mem: 8337
# Epoch: [195]  [10/30]  eta: 0:01:02  lr: 0.000000  loss: 0.2577 (0.2700)  loss_classifier: 0.1215 (0.1256)  loss_box_reg: 0.0796 (0.0871)  loss_objectness: 0.0467 (0.0506)  loss_rpn_box_reg: 0.0058 (0.0067)  time: 3.1443  data: 1.9735  max mem: 8337
# Epoch: [195]  [20/30]  eta: 0:00:31  lr: 0.000000  loss: 0.2532 (0.2582)  loss_classifier: 0.1151 (0.1205)  loss_box_reg: 0.0786 (0.0827)  loss_objectness: 0.0460 (0.0489)  loss_rpn_box_reg: 0.0048 (0.0060)  time: 3.1588  data: 1.9877  max mem: 8337
# Epoch: [195]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2467 (0.2533)  loss_classifier: 0.1112 (0.1187)  loss_box_reg: 0.0772 (0.0814)  loss_objectness: 0.0477 (0.0473)  loss_rpn_box_reg: 0.0047 (0.0059)  time: 3.0547  data: 1.9280  max mem: 8337
# Epoch: [195] Total time: 0:01:32 (3.0860 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4381 (0.4381)  evaluator_time: 0.0190 (0.0190)  time: 2.7156  data: 1.8824  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4381 (0.4018)  evaluator_time: 0.0180 (0.0153)  time: 2.4043  data: 1.7601  max mem: 8337
# Test: Total time: 0:00:16 (2.4043 s / it)
# Averaged stats: model_time: 0.4381 (0.4018)  evaluator_time: 0.0180 (0.0153)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [196]  [ 0/30]  eta: 0:01:33  lr: 0.000000  loss: 0.1175 (0.1175)  loss_classifier: 0.0571 (0.0571)  loss_box_reg: 0.0384 (0.0384)  loss_objectness: 0.0202 (0.0202)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 3.1044  data: 1.9274  max mem: 8337
# Epoch: [196]  [10/30]  eta: 0:01:03  lr: 0.000000  loss: 0.2465 (0.2409)  loss_classifier: 0.1112 (0.1105)  loss_box_reg: 0.0797 (0.0767)  loss_objectness: 0.0475 (0.0473)  loss_rpn_box_reg: 0.0056 (0.0063)  time: 3.1732  data: 1.9924  max mem: 8337
# Epoch: [196]  [20/30]  eta: 0:00:31  lr: 0.000000  loss: 0.2452 (0.2449)  loss_classifier: 0.1104 (0.1142)  loss_box_reg: 0.0797 (0.0795)  loss_objectness: 0.0442 (0.0452)  loss_rpn_box_reg: 0.0054 (0.0060)  time: 3.1801  data: 2.0055  max mem: 8337
# Epoch: [196]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2828 (0.2577)  loss_classifier: 0.1198 (0.1205)  loss_box_reg: 0.0828 (0.0825)  loss_objectness: 0.0459 (0.0487)  loss_rpn_box_reg: 0.0054 (0.0060)  time: 3.0617  data: 1.9330  max mem: 8337
# Epoch: [196] Total time: 0:01:32 (3.0980 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4371 (0.4371)  evaluator_time: 0.0180 (0.0180)  time: 2.7766  data: 1.9124  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4391 (0.4052)  evaluator_time: 0.0170 (0.0136)  time: 2.4118  data: 1.7611  max mem: 8337
# Test: Total time: 0:00:16 (2.4119 s / it)
# Averaged stats: model_time: 0.4391 (0.4052)  evaluator_time: 0.0170 (0.0136)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [197]  [ 0/30]  eta: 0:01:34  lr: 0.000000  loss: 0.2236 (0.2236)  loss_classifier: 0.1091 (0.1091)  loss_box_reg: 0.0716 (0.0716)  loss_objectness: 0.0395 (0.0395)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 3.1441  data: 1.9864  max mem: 8337
# Epoch: [197]  [10/30]  eta: 0:01:03  lr: 0.000000  loss: 0.2717 (0.2820)  loss_classifier: 0.1303 (0.1323)  loss_box_reg: 0.0919 (0.0912)  loss_objectness: 0.0545 (0.0520)  loss_rpn_box_reg: 0.0057 (0.0066)  time: 3.1686  data: 1.9895  max mem: 8337
# Epoch: [197]  [20/30]  eta: 0:00:31  lr: 0.000000  loss: 0.2562 (0.2664)  loss_classifier: 0.1188 (0.1253)  loss_box_reg: 0.0839 (0.0873)  loss_objectness: 0.0491 (0.0481)  loss_rpn_box_reg: 0.0051 (0.0057)  time: 3.1777  data: 2.0014  max mem: 8337
# Epoch: [197]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2431 (0.2522)  loss_classifier: 0.1133 (0.1181)  loss_box_reg: 0.0817 (0.0812)  loss_objectness: 0.0481 (0.0471)  loss_rpn_box_reg: 0.0051 (0.0058)  time: 3.0753  data: 1.9443  max mem: 8337
# Epoch: [197] Total time: 0:01:33 (3.1058 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4351 (0.4351)  evaluator_time: 0.0200 (0.0200)  time: 2.7946  data: 1.9644  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4581 (0.4157)  evaluator_time: 0.0150 (0.0129)  time: 2.4082  data: 1.7530  max mem: 8337
# Test: Total time: 0:00:16 (2.4085 s / it)
# Averaged stats: model_time: 0.4581 (0.4157)  evaluator_time: 0.0150 (0.0129)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [198]  [ 0/30]  eta: 0:01:30  lr: 0.000000  loss: 0.2317 (0.2317)  loss_classifier: 0.1046 (0.1046)  loss_box_reg: 0.0721 (0.0721)  loss_objectness: 0.0489 (0.0489)  loss_rpn_box_reg: 0.0061 (0.0061)  time: 3.0134  data: 1.8584  max mem: 8337
# Epoch: [198]  [10/30]  eta: 0:01:03  lr: 0.000000  loss: 0.2179 (0.2200)  loss_classifier: 0.1043 (0.1049)  loss_box_reg: 0.0667 (0.0687)  loss_objectness: 0.0428 (0.0419)  loss_rpn_box_reg: 0.0042 (0.0045)  time: 3.1584  data: 1.9914  max mem: 8337
# Epoch: [198]  [20/30]  eta: 0:00:31  lr: 0.000000  loss: 0.2244 (0.2366)  loss_classifier: 0.1043 (0.1120)  loss_box_reg: 0.0685 (0.0755)  loss_objectness: 0.0402 (0.0439)  loss_rpn_box_reg: 0.0042 (0.0053)  time: 3.1741  data: 2.0001  max mem: 8337
# Epoch: [198]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2577 (0.2561)  loss_classifier: 0.1192 (0.1202)  loss_box_reg: 0.0862 (0.0826)  loss_objectness: 0.0471 (0.0476)  loss_rpn_box_reg: 0.0049 (0.0058)  time: 3.0715  data: 1.9347  max mem: 8337
# Epoch: [198] Total time: 0:01:32 (3.0992 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4371 (0.4371)  evaluator_time: 0.0190 (0.0190)  time: 2.8306  data: 1.9464  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4371 (0.3982)  evaluator_time: 0.0140 (0.0137)  time: 2.3990  data: 1.7537  max mem: 8337
# Test: Total time: 0:00:16 (2.3990 s / it)
# Averaged stats: model_time: 0.4371 (0.3982)  evaluator_time: 0.0140 (0.0137)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# Epoch: [199]  [ 0/30]  eta: 0:01:32  lr: 0.000000  loss: 0.3179 (0.3179)  loss_classifier: 0.1509 (0.1509)  loss_box_reg: 0.1125 (0.1125)  loss_objectness: 0.0479 (0.0479)  loss_rpn_box_reg: 0.0067 (0.0067)  time: 3.0810  data: 1.8824  max mem: 8337
# Epoch: [199]  [10/30]  eta: 0:01:02  lr: 0.000000  loss: 0.2501 (0.2564)  loss_classifier: 0.1149 (0.1193)  loss_box_reg: 0.0740 (0.0805)  loss_objectness: 0.0505 (0.0502)  loss_rpn_box_reg: 0.0043 (0.0064)  time: 3.1498  data: 1.9721  max mem: 8337
# Epoch: [199]  [20/30]  eta: 0:00:31  lr: 0.000000  loss: 0.2341 (0.2533)  loss_classifier: 0.1043 (0.1188)  loss_box_reg: 0.0738 (0.0804)  loss_objectness: 0.0483 (0.0482)  loss_rpn_box_reg: 0.0052 (0.0059)  time: 3.1597  data: 1.9868  max mem: 8337
# Epoch: [199]  [29/30]  eta: 0:00:03  lr: 0.000000  loss: 0.2213 (0.2506)  loss_classifier: 0.1089 (0.1174)  loss_box_reg: 0.0754 (0.0801)  loss_objectness: 0.0406 (0.0472)  loss_rpn_box_reg: 0.0050 (0.0058)  time: 3.0616  data: 1.9301  max mem: 8337
# Epoch: [199] Total time: 0:01:32 (3.0900 s / it)
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:19  model_time: 0.4391 (0.4391)  evaluator_time: 0.0180 (0.0180)  time: 2.8006  data: 1.9094  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4391 (0.4019)  evaluator_time: 0.0100 (0.0110)  time: 2.4180  data: 1.7695  max mem: 8337
# Test: Total time: 0:00:16 (2.4181 s / it)
# Averaged stats: model_time: 0.4391 (0.4019)  evaluator_time: 0.0100 (0.0110)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# ====================| Training Done, start testing! | Training time: [24715] seconds, Avg time / Epoch: [123.575] seconds====================
# creating index...
# index created!
# Test:  [0/7]  eta: 0:00:20  model_time: 0.4351 (0.4351)  evaluator_time: 0.0190 (0.0190)  time: 2.8706  data: 1.9264  max mem: 8337
# Test:  [6/7]  eta: 0:00:02  model_time: 0.4391 (0.4065)  evaluator_time: 0.0130 (0.0136)  time: 2.4317  data: 1.7678  max mem: 8337
# Test: Total time: 0:00:17 (2.4318 s / it)
# Averaged stats: model_time: 0.4391 (0.4065)  evaluator_time: 0.0130 (0.0136)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.048

# %%
test_evaluator.summarize()
# Out:
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.048

# %%
clinial_cond = "With" if model.use_clinical else "Without"
current_time_string = datetime.now().strftime("%m-%d-%Y %H-%M-%S")
final_model_path =  f"epoch{epoch}_{clinial_cond}Clincal_{current_time_string}".replace(":", "_").replace(".", "_")

# %%
# final_model_path = 'epoch199_WithClincal_2022-03-07 18_01_13_075135'
final_model_path = 'epoch199_WithClincal_03-07-2022 18-04-34'

# %%
training_record = OrderedDict({
    "train_logers": train_logers,
    "val_evaluators" : val_evaluators,
    "test_evaluator": test_evaluator,
})

# %%
torch.save(model.state_dict(), os.path.join(
    os.path.join('trained_models', final_model_path)
))

# %%
with open(
    os.path.join("train_hist", f"{final_model_path}.pkl"), "wb",
) as training_record_f:
    pickle.dump(training_record, training_record_f)

# %%
# # load testing.
# import pickle
final_model_path = "epoch199_WithClincal_03-07-2022 18-04-34"
with open(os.path.join("train_hist", f"{final_model_path}.pkl"), 'rb') as f:
    train_hist = pickle.load(f)

# %%
final_model_path = "epoch199_WithClincal_03-07-2022 18-04-34"

# %%
os.path.join("train_hist", f"{final_model_path}.pkl")
# Out:
# 'train_hist\\epoch199_WithClincal_03-07-2022 18-04-34.pkl'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31700\3151121285.py in <module>
# ----> 1 train_hist
#
# NameError: name 'train_hist' is not defined
